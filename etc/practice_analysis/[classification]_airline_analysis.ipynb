# %% [markdown]
# ### Airline analysis(predict to Delay)

# %%
import pandas as pd
from pandasql import sqldf
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/yoo/Data-dev/etc/practice_analysis/Airlines.csv')
print(df.shape)

df.head(10)
# Out:
# (539383, 9)
#    id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  Delay
# 0   1      CO     269         SFO       IAH          3    15     205      1
# 1   2      US    1558         PHX       CLT          3    15     222      1
# 2   3      AA    2400         LAX       DFW          3    20     165      1
# 3   4      AA    2466         SFO       DFW          3    20     195      1
# 4   5      AS     108         ANC       SEA          3    30     202      0
# 5   6      CO    1094         LAX       IAH          3    30     181      1
# 6   7      DL    1768         LAX       MSP          3    30     220      0
# 7   8      DL    2722         PHX       DTW          3    30     228      0
# 8   9      DL    2606         SFO       MSP          3    35     216      1
# 9  10      AA    2538         LAS       ORD          3    40     200      1

# %%
print(df.Airline.nunique())
df.Airline.value_counts().plot(figsize=(10,6), kind='bar')
# Out:
# 18
# <AxesSubplot:>

# %%
df_summary = df[['Airline', 'AirportFrom', 'AirportTo', 'Flight', 'DayOfWeek', 'Time', 'Length', 'Delay']].groupby(by=['Airline','AirportFrom','AirportTo']).sum().sort_values(by='Delay', ascending=False)
df_summary
# Out:
#                                 Flight  DayOfWeek    Time  Length  Delay
# Airline AirportFrom AirportTo
# WN      DAL         HOU         137815       2669  557895   43285    477
#         HOU         DAL         134371       2648  569625   40010    451
#         OAK         LAX         620747       1569  309760   30015    315
#         LAS         PHX         584001       1543  338720   27435    300
# AA      ORD         DFW        1050117       1778  366820   68720    285
# ...                                ...        ...     ...     ...    ...
# YV      IAD         PWM          14566         14    1474     184      0
# EV      DTW         XNA           4957          6     940     140      0
# YV      IAD         SAV           7284          5    1012     106      0
#         IAH         IAD           7245          6     723     178      0
# OH      MEM         GRR           6271          5    1135     109      0
#
# [6836 rows x 5 columns]

# %%
query = """
select DayOfWeek
     , Delay
     , count(*) cnt
from
(
    select Airline
        , Flight
        , AirportFrom
        , AirportTo
        , DayOfWeek
        , Time
        , Length
        , Delay
    from df
)
group by 1,2
order by 3 desc
;
"""

sqldf(query)
# Out:
#     DayOfWeek  Delay    cnt
# 0           4      0  50201
# 1           5      0  49733
# 2           3      0  47492
# 3           3      1  42254
# 4           4      1  41244
# 5           2      0  39427
# 6           1      0  38739
# 7           7      0  38186
# 8           5      1  35515
# 9           6      0  35341
# 10          1      1  34030
# 11          2      1  31913
# 12          7      1  31693
# 13          6      1  23615

# %%
# binary classification

df.Delay.value_counts()
# Out:
# 0    299119
# 1    240264
# Name: Delay, dtype: int64

# %%
print(df.isnull().sum())
df.isnull().sum().plot(kind='bar')
# Out:
# id             0
# Airline        0
# Flight         0
# AirportFrom    0
# AirportTo      0
# DayOfWeek      0
# Time           0
# Length         0
# Delay          0
# dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ### Logistic Regression

# %%
print(df.head(10))

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

from sklearn.metrics import r2_score, roc_auc_score
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()
# Out:
#    id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  Delay
# 0   1      CO     269         SFO       IAH          3    15     205      1
# 1   2      US    1558         PHX       CLT          3    15     222      1
# 2   3      AA    2400         LAX       DFW          3    20     165      1
# 3   4      AA    2466         SFO       DFW          3    20     195      1
# 4   5      AS     108         ANC       SEA          3    30     202      0
# 5   6      CO    1094         LAX       IAH          3    30     181      1
# 6   7      DL    1768         LAX       MSP          3    30     220      0
# 7   8      DL    2722         PHX       DTW          3    30     228      0
# 8   9      DL    2606         SFO       MSP          3    35     216      1
# 9  10      AA    2538         LAS       ORD          3    40     200      1

# %%
# check dimension table

df_category_encoder = pd.DataFrame(encoder.fit_transform(df[['Airline', 'AirportFrom', 'AirportTo']]), columns=['Airline', 'AirportFrom', 'AirportTo'])

df_dimension = pd.concat([df, df_category_encoder], axis=1)
df_dimension
# Out:
#             id  Airline  Flight  AirportFrom  AirportTo  DayOfWeek  Time  \
# 0            1       CO     269          SFO        IAH          3    15
# 1            2       US    1558          PHX        CLT          3    15
# 2            3       AA    2400          LAX        DFW          3    20
# 3            4       AA    2466          SFO        DFW          3    20
# 4            5       AS     108          ANC        SEA          3    30
# ...        ...      ...     ...          ...        ...        ...   ...
# 539378  539379       CO     178          OGG        SNA          5  1439
# 539379  539380       FL     398          SEA        ATL          5  1439
# 539380  539381       FL     609          SFO        MKE          5  1439
# 539381  539382       UA      78          HNL        SFO          5  1439
# 539382  539383       US    1442          LAX        PHL          5  1439
#
#         Length  Delay  Airline  AirportFrom  AirportTo
# 0          205      1      4.0        253.0      135.0
# 1          222      1     14.0        217.0       60.0
# 2          165      1      1.0        154.0       80.0
# 3          195      1      1.0        253.0       80.0
# 4          202      0      2.0         14.0      252.0
# ...        ...    ...      ...          ...        ...
# 539378     326      0      4.0        203.0      264.0
# 539379     305      0      8.0        252.0       16.0
# 539380     255      0      8.0        253.0      184.0
# 539381     313      1     13.0        128.0      253.0
# 539382     301      1     14.0        154.0      216.0
#
# [539383 rows x 12 columns]

# %%
df_f = pd.concat([df_category_encoder, df[['Flight', 'DayOfWeek', 'Time', 'Length', 'Delay']]], axis=1)
df_f
# Out:
#         Airline  AirportFrom  AirportTo  Flight  DayOfWeek  Time  Length  \
# 0           4.0        253.0      135.0     269          3    15     205
# 1          14.0        217.0       60.0    1558          3    15     222
# 2           1.0        154.0       80.0    2400          3    20     165
# 3           1.0        253.0       80.0    2466          3    20     195
# 4           2.0         14.0      252.0     108          3    30     202
# ...         ...          ...        ...     ...        ...   ...     ...
# 539378      4.0        203.0      264.0     178          5  1439     326
# 539379      8.0        252.0       16.0     398          5  1439     305
# 539380      8.0        253.0      184.0     609          5  1439     255
# 539381     13.0        128.0      253.0      78          5  1439     313
# 539382     14.0        154.0      216.0    1442          5  1439     301
#
#         Delay
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# ...       ...
# 539378      0
# 539379      0
# 539380      0
# 539381      1
# 539382      1
#
# [539383 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df_f.iloc[:,:-1], df_f.iloc[:,-1:], test_size=0.3, random_state=9095)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (377568, 7) (161815, 7) (377568, 1) (161815, 1)

# %%
lr.fit(x_train, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LogisticRegression()

# %%
lr.predict_proba(x_train)
# Out:
# array([[0.45829107, 0.54170893],
#        [0.51999062, 0.48000938],
#        [0.38293159, 0.61706841],
#        ...,
#        [0.62115402, 0.37884598],
#        [0.47742325, 0.52257675],
#        [0.53275697, 0.46724303]])

# %%
print(f'linear logistic regression score: {round(lr.score(x_train, y_train)*100,2)}%')
# Out:
# linear logistic regression score: 56.89%

# %% [markdown]
# ### XGBoost Classification

# %%
# %%time

from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
xgbc = XGBClassifier()

xgb_params_grid = {
    'n_estimators': [n for n in range(100, 500, 100)],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [2,4,6]
}

xgb_grid = GridSearchCV(xgbc, param_grid=xgb_params_grid, scoring='roc_auc', n_jobs=-1)
xgb_grid.fit(x_train, y_train)

# %%
print(f'최고 파라미터: {xgb_params_grid.best_score_}')
xgb_params_grid.best_params_

# %%
xgb = XGBClassifier(n_estimators = 700, learning_rate = 0.5, max_depth=6)
evals = [(x_test, y_test)]
xgb.fit(x_train, y_train, early_stopping_rounds = 200, eval_metric = 'auc', eval_set=evals)
# Out:
# [0]	validation_0-auc:0.67802
# [1]	validation_0-auc:0.68213
# [2]	validation_0-auc:0.68561
# [3]	validation_0-auc:0.68783
# [4]	validation_0-auc:0.68974
# [5]	validation_0-auc:0.69168
# [6]	validation_0-auc:0.69456
# [7]	validation_0-auc:0.69673
# [8]	validation_0-auc:0.69781
# [9]	validation_0-auc:0.69923
# [10]	validation_0-auc:0.69993
# [11]	validation_0-auc:0.70039
# [12]	validation_0-auc:0.70062
# [13]	validation_0-auc:0.70118
# [14]	validation_0-auc:0.70194
# [15]	validation_0-auc:0.70274
# [16]	validation_0-auc:0.70348
# [17]	validation_0-auc:0.70380
# [18]	validation_0-auc:0.70409
# [19]	validation_0-auc:0.70475
# [20]	validation_0-auc:0.70544
# [21]	validation_0-auc:0.70549
# [22]	validation_0-auc:0.70580
# [23]	validation_0-auc:0.70604
# [24]	validation_0-auc:0.70653
# [25]	validation_0-auc:0.70652
# [26]	validation_0-auc:0.70691
# [27]	validation_0-auc:0.70727
# [28]	validation_0-auc:0.70750
# [29]	validation_0-auc:0.70764
# [30]	validation_0-auc:0.70807
# [31]	validation_0-auc:0.70818
# [32]	validation_0-auc:0.70822
# [33]	validation_0-auc:0.70830
# [34]	validation_0-auc:0.70849
# [35]	validation_0-auc:0.70911
# [36]	validation_0-auc:0.70938
# [37]	validation_0-auc:0.70954
# [38]	validation_0-auc:0.70958
# [39]	validation_0-auc:0.70966
# [40]	validation_0-auc:0.70969
# [41]	validation_0-auc:0.71002
# [42]	validation_0-auc:0.71032
# [43]	validation_0-auc:0.71048
# [44]	validation_0-auc:0.71057
# [45]	validation_0-auc:0.71063
# [46]	validation_0-auc:0.71083
# [47]	validation_0-auc:0.71091
# [48]	validation_0-auc:0.71114
# [49]	validation_0-auc:0.71139
# [50]	validation_0-auc:0.71152
# [51]	validation_0-auc:0.71168
# [52]	validation_0-auc:0.71178
# [53]	validation_0-auc:0.71180
# [54]	validation_0-auc:0.71176
# [55]	validation_0-auc:0.71176
# [56]	validation_0-auc:0.71181
# [57]	validation_0-auc:0.71184
# [58]	validation_0-auc:0.71203
# [59]	validation_0-auc:0.71209
# [60]	validation_0-auc:0.71213
# [61]	validation_0-auc:0.71216
# [62]	validation_0-auc:0.71225
# [63]	validation_0-auc:0.71230
# [64]	validation_0-auc:0.71237
# [65]	validation_0-auc:0.71239
# [66]	validation_0-auc:0.71237
# [67]	validation_0-auc:0.71267
# [68]	validation_0-auc:0.71288
# [69]	validation_0-auc:0.71289
# [70]	validation_0-auc:0.71290
# [71]	validation_0-auc:0.71284
# [72]	validation_0-auc:0.71296
# [73]	validation_0-auc:0.71293
# [74]	validation_0-auc:0.71310
# [75]	validation_0-auc:0.71314
# [76]	validation_0-auc:0.71320
# [77]	validation_0-auc:0.71318
# [78]	validation_0-auc:0.71327
# [79]	validation_0-auc:0.71333
# [80]	validation_0-auc:0.71349
# [81]	validation_0-auc:0.71356
# [82]	validation_0-auc:0.71362
# [83]	validation_0-auc:0.71369
# [84]	validation_0-auc:0.71368
# [85]	validation_0-auc:0.71371
# [86]	validation_0-auc:0.71371
# [87]	validation_0-auc:0.71374
# [88]	validation_0-auc:0.71393
# [89]	validation_0-auc:0.71408
# [90]	validation_0-auc:0.71410
# [91]	validation_0-auc:0.71414
# [92]	validation_0-auc:0.71419
# [93]	validation_0-auc:0.71444
# [94]	validation_0-auc:0.71448
# [95]	validation_0-auc:0.71453
# [96]	validation_0-auc:0.71448
# [97]	validation_0-auc:0.71448
# [98]	validation_0-auc:0.71456
# [99]	validation_0-auc:0.71463
# [100]	validation_0-auc:0.71477
# [101]	validation_0-auc:0.71482
# [102]	validation_0-auc:0.71493
# [103]	validation_0-auc:0.71502
# [104]	validation_0-auc:0.71498
# [105]	validation_0-auc:0.71496
# [106]	validation_0-auc:0.71513
# [107]	validation_0-auc:0.71522
# [108]	validation_0-auc:0.71527
# [109]	validation_0-auc:0.71525
# [110]	validation_0-auc:0.71535
# [111]	validation_0-auc:0.71542
# [112]	validation_0-auc:0.71557
# [113]	validation_0-auc:0.71566
# [114]	validation_0-auc:0.71571
# [115]	validation_0-auc:0.71571
# [116]	validation_0-auc:0.71568
# [117]	validation_0-auc:0.71566
# [118]	validation_0-auc:0.71569
# [119]	validation_0-auc:0.71575
# [120]	validation_0-auc:0.71580
# [121]	validation_0-auc:0.71591
# [122]	validation_0-auc:0.71586
# [123]	validation_0-auc:0.71588
# [124]	validation_0-auc:0.71595
# [125]	validation_0-auc:0.71595
# [126]	validation_0-auc:0.71604
# [127]	validation_0-auc:0.71611
# [128]	validation_0-auc:0.71614
# [129]	validation_0-auc:0.71609
# [130]	validation_0-auc:0.71609
# [131]	validation_0-auc:0.71614
# [132]	validation_0-auc:0.71608
# [133]	validation_0-auc:0.71600
# [134]	validation_0-auc:0.71615
# [135]	validation_0-auc:0.71619
# [136]	validation_0-auc:0.71619
# [137]	validation_0-auc:0.71621
# [138]	validation_0-auc:0.71628
# [139]	validation_0-auc:0.71632
# [140]	validation_0-auc:0.71629
# [141]	validation_0-auc:0.71631
# [142]	validation_0-auc:0.71637
# [143]	validation_0-auc:0.71643
# [144]	validation_0-auc:0.71640
# [145]	validation_0-auc:0.71648
# [146]	validation_0-auc:0.71652
# [147]	validation_0-auc:0.71655
# [148]	validation_0-auc:0.71653
# [149]	validation_0-auc:0.71653
# [150]	validation_0-auc:0.71652
# [151]	validation_0-auc:0.71654
# [152]	validation_0-auc:0.71659
# [153]	validation_0-auc:0.71669
# [154]	validation_0-auc:0.71669
# [155]	validation_0-auc:0.71665
# [156]	validation_0-auc:0.71664
# [157]	validation_0-auc:0.71669
# [158]	validation_0-auc:0.71676
# [159]	validation_0-auc:0.71686
# [160]	validation_0-auc:0.71683
# [161]	validation_0-auc:0.71693
# [162]	validation_0-auc:0.71693
# [163]	validation_0-auc:0.71692
# [164]	validation_0-auc:0.71692
# [165]	validation_0-auc:0.71690
# [166]	validation_0-auc:0.71693
# [167]	validation_0-auc:0.71707
# [168]	validation_0-auc:0.71713
# [169]	validation_0-auc:0.71716
# [170]	validation_0-auc:0.71717
# [171]	validation_0-auc:0.71716
# [172]	validation_0-auc:0.71718
# [173]	validation_0-auc:0.71717
# [174]	validation_0-auc:0.71716
# [175]	validation_0-auc:0.71721
# [176]	validation_0-auc:0.71725
# [177]	validation_0-auc:0.71725
# [178]	validation_0-auc:0.71728
# [179]	validation_0-auc:0.71724
# [180]	validation_0-auc:0.71727
# [181]	validation_0-auc:0.71731
# [182]	validation_0-auc:0.71733
# [183]	validation_0-auc:0.71731
# [184]	validation_0-auc:0.71739
# [185]	validation_0-auc:0.71741
# [186]	validation_0-auc:0.71740
# [187]	validation_0-auc:0.71740
# [188]	validation_0-auc:0.71736
# [189]	validation_0-auc:0.71735
# [190]	validation_0-auc:0.71746
# [191]	validation_0-auc:0.71744
# [192]	validation_0-auc:0.71744
# [193]	validation_0-auc:0.71750
# [194]	validation_0-auc:0.71746
# [195]	validation_0-auc:0.71746
# [196]	validation_0-auc:0.71750
# [197]	validation_0-auc:0.71749
# [198]	validation_0-auc:0.71751
# [199]	validation_0-auc:0.71747
# [200]	validation_0-auc:0.71738
# [201]	validation_0-auc:0.71744
# [202]	validation_0-auc:0.71743
# [203]	validation_0-auc:0.71741
# [204]	validation_0-auc:0.71751
# [205]	validation_0-auc:0.71748
# [206]	validation_0-auc:0.71750
# [207]	validation_0-auc:0.71749
# [208]	validation_0-auc:0.71748
# [209]	validation_0-auc:0.71753
# [210]	validation_0-auc:0.71748
# [211]	validation_0-auc:0.71745
# [212]	validation_0-auc:0.71743
# [213]	validation_0-auc:0.71743
# [214]	validation_0-auc:0.71744
# [215]	validation_0-auc:0.71743
# [216]	validation_0-auc:0.71743
# [217]	validation_0-auc:0.71747
# [218]	validation_0-auc:0.71745
# [219]	validation_0-auc:0.71739
# [220]	validation_0-auc:0.71738
# [221]	validation_0-auc:0.71735
# [222]	validation_0-auc:0.71732
# [223]	validation_0-auc:0.71733
# [224]	validation_0-auc:0.71734
# [225]	validation_0-auc:0.71733
# [226]	validation_0-auc:0.71731
# [227]	validation_0-auc:0.71731
# [228]	validation_0-auc:0.71730
# [229]	validation_0-auc:0.71729
# [230]	validation_0-auc:0.71725
# [231]	validation_0-auc:0.71726
# [232]	validation_0-auc:0.71728
# [233]	validation_0-auc:0.71727
# [234]	validation_0-auc:0.71727
# [235]	validation_0-auc:0.71727
# [236]	validation_0-auc:0.71731
# [237]	validation_0-auc:0.71731
# [238]	validation_0-auc:0.71734
# [239]	validation_0-auc:0.71737
# [240]	validation_0-auc:0.71737
# [241]	validation_0-auc:0.71739
# [242]	validation_0-auc:0.71747
# [243]	validation_0-auc:0.71754
# [244]	validation_0-auc:0.71757
# [245]	validation_0-auc:0.71759
# [246]	validation_0-auc:0.71760
# [247]	validation_0-auc:0.71764
# [248]	validation_0-auc:0.71761
# [249]	validation_0-auc:0.71762
# [250]	validation_0-auc:0.71767
# [251]	validation_0-auc:0.71786
# [252]	validation_0-auc:0.71790
# [253]	validation_0-auc:0.71788
# [254]	validation_0-auc:0.71791
# [255]	validation_0-auc:0.71793
# [256]	validation_0-auc:0.71792
# [257]	validation_0-auc:0.71783
# [258]	validation_0-auc:0.71784
# [259]	validation_0-auc:0.71785
# [260]	validation_0-auc:0.71793
# [261]	validation_0-auc:0.71798
# [262]	validation_0-auc:0.71801
# [263]	validation_0-auc:0.71799
# [264]	validation_0-auc:0.71801
# [265]	validation_0-auc:0.71800
# [266]	validation_0-auc:0.71798
# [267]	validation_0-auc:0.71798
# [268]	validation_0-auc:0.71796
# [269]	validation_0-auc:0.71797
# [270]	validation_0-auc:0.71787
# [271]	validation_0-auc:0.71787
# [272]	validation_0-auc:0.71789
# [273]	validation_0-auc:0.71788
# [274]	validation_0-auc:0.71793
# [275]	validation_0-auc:0.71790
# [276]	validation_0-auc:0.71793
# [277]	validation_0-auc:0.71791
# [278]	validation_0-auc:0.71795
# [279]	validation_0-auc:0.71798
# [280]	validation_0-auc:0.71798
# [281]	validation_0-auc:0.71796
# [282]	validation_0-auc:0.71792
# [283]	validation_0-auc:0.71789
# [284]	validation_0-auc:0.71781
# [285]	validation_0-auc:0.71781
# [286]	validation_0-auc:0.71781
# [287]	validation_0-auc:0.71781
# [288]	validation_0-auc:0.71781
# [289]	validation_0-auc:0.71781
# [290]	validation_0-auc:0.71780
# [291]	validation_0-auc:0.71776
# [292]	validation_0-auc:0.71782
# [293]	validation_0-auc:0.71787
# [294]	validation_0-auc:0.71784
# [295]	validation_0-auc:0.71782
# [296]	validation_0-auc:0.71789
# [297]	validation_0-auc:0.71787
# [298]	validation_0-auc:0.71791
# [299]	validation_0-auc:0.71792
# [300]	validation_0-auc:0.71787
# [301]	validation_0-auc:0.71791
# [302]	validation_0-auc:0.71788
# [303]	validation_0-auc:0.71795
# [304]	validation_0-auc:0.71794
# [305]	validation_0-auc:0.71793
# [306]	validation_0-auc:0.71787
# [307]	validation_0-auc:0.71788
# [308]	validation_0-auc:0.71787
# [309]	validation_0-auc:0.71787
# [310]	validation_0-auc:0.71789
# [311]	validation_0-auc:0.71788
# [312]	validation_0-auc:0.71785
# [313]	validation_0-auc:0.71788
# [314]	validation_0-auc:0.71786
# [315]	validation_0-auc:0.71783
# [316]	validation_0-auc:0.71781
# [317]	validation_0-auc:0.71781
# [318]	validation_0-auc:0.71785
# [319]	validation_0-auc:0.71782
# [320]	validation_0-auc:0.71780
# [321]	validation_0-auc:0.71782
# [322]	validation_0-auc:0.71786
# [323]	validation_0-auc:0.71784
# [324]	validation_0-auc:0.71782
# [325]	validation_0-auc:0.71783
# [326]	validation_0-auc:0.71781
# [327]	validation_0-auc:0.71790
# [328]	validation_0-auc:0.71790
# [329]	validation_0-auc:0.71792
# [330]	validation_0-auc:0.71792
# [331]	validation_0-auc:0.71790
# [332]	validation_0-auc:0.71788
# [333]	validation_0-auc:0.71791
# [334]	validation_0-auc:0.71789
# [335]	validation_0-auc:0.71794
# [336]	validation_0-auc:0.71794
# [337]	validation_0-auc:0.71793
# [338]	validation_0-auc:0.71794
# [339]	validation_0-auc:0.71793
# [340]	validation_0-auc:0.71793
# [341]	validation_0-auc:0.71795
# [342]	validation_0-auc:0.71798
# [343]	validation_0-auc:0.71798
# [344]	validation_0-auc:0.71796
# [345]	validation_0-auc:0.71798
# [346]	validation_0-auc:0.71790
# [347]	validation_0-auc:0.71790
# [348]	validation_0-auc:0.71786
# [349]	validation_0-auc:0.71784
# [350]	validation_0-auc:0.71779
# [351]	validation_0-auc:0.71778
# [352]	validation_0-auc:0.71778
# [353]	validation_0-auc:0.71777
# [354]	validation_0-auc:0.71779
# [355]	validation_0-auc:0.71782
# [356]	validation_0-auc:0.71781
# [357]	validation_0-auc:0.71782
# [358]	validation_0-auc:0.71782
# [359]	validation_0-auc:0.71782
# [360]	validation_0-auc:0.71781
# [361]	validation_0-auc:0.71785
# [362]	validation_0-auc:0.71787
# [363]	validation_0-auc:0.71784
# [364]	validation_0-auc:0.71781
# [365]	validation_0-auc:0.71780
# [366]	validation_0-auc:0.71778
# [367]	validation_0-auc:0.71777
# [368]	validation_0-auc:0.71773
# [369]	validation_0-auc:0.71774
# [370]	validation_0-auc:0.71770
# [371]	validation_0-auc:0.71766
# [372]	validation_0-auc:0.71765
# [373]	validation_0-auc:0.71765
# [374]	validation_0-auc:0.71764
# [375]	validation_0-auc:0.71768
# [376]	validation_0-auc:0.71772
# [377]	validation_0-auc:0.71769
# [378]	validation_0-auc:0.71770
# [379]	validation_0-auc:0.71773
# [380]	validation_0-auc:0.71774
# [381]	validation_0-auc:0.71775
# [382]	validation_0-auc:0.71775
# [383]	validation_0-auc:0.71775
# [384]	validation_0-auc:0.71772
# [385]	validation_0-auc:0.71775
# [386]	validation_0-auc:0.71777
# [387]	validation_0-auc:0.71778
# [388]	validation_0-auc:0.71776
# [389]	validation_0-auc:0.71775
# [390]	validation_0-auc:0.71774
# [391]	validation_0-auc:0.71770
# [392]	validation_0-auc:0.71770
# [393]	validation_0-auc:0.71766
# [394]	validation_0-auc:0.71764
# [395]	validation_0-auc:0.71762
# [396]	validation_0-auc:0.71763
# [397]	validation_0-auc:0.71762
# [398]	validation_0-auc:0.71760
# [399]	validation_0-auc:0.71763
# [400]	validation_0-auc:0.71762
# [401]	validation_0-auc:0.71761
# [402]	validation_0-auc:0.71760
# [403]	validation_0-auc:0.71755
# [404]	validation_0-auc:0.71756
# [405]	validation_0-auc:0.71755
# [406]	validation_0-auc:0.71752
# [407]	validation_0-auc:0.71755
# [408]	validation_0-auc:0.71753
# [409]	validation_0-auc:0.71758
# [410]	validation_0-auc:0.71756
# [411]	validation_0-auc:0.71756
# [412]	validation_0-auc:0.71753
# [413]	validation_0-auc:0.71747
# [414]	validation_0-auc:0.71746
# [415]	validation_0-auc:0.71743
# [416]	validation_0-auc:0.71744
# [417]	validation_0-auc:0.71733
# [418]	validation_0-auc:0.71738
# [419]	validation_0-auc:0.71736
# [420]	validation_0-auc:0.71732
# [421]	validation_0-auc:0.71726
# [422]	validation_0-auc:0.71726
# [423]	validation_0-auc:0.71727
# [424]	validation_0-auc:0.71730
# [425]	validation_0-auc:0.71728
# [426]	validation_0-auc:0.71727
# [427]	validation_0-auc:0.71728
# [428]	validation_0-auc:0.71728
# [429]	validation_0-auc:0.71728
# [430]	validation_0-auc:0.71726
# [431]	validation_0-auc:0.71727
# [432]	validation_0-auc:0.71725
# [433]	validation_0-auc:0.71724
# [434]	validation_0-auc:0.71723
# [435]	validation_0-auc:0.71724
# [436]	validation_0-auc:0.71727
# [437]	validation_0-auc:0.71717
# [438]	validation_0-auc:0.71719
# [439]	validation_0-auc:0.71719
# [440]	validation_0-auc:0.71716
# [441]	validation_0-auc:0.71714
# [442]	validation_0-auc:0.71710
# [443]	validation_0-auc:0.71708
# [444]	validation_0-auc:0.71704
# [445]	validation_0-auc:0.71704
# [446]	validation_0-auc:0.71703
# [447]	validation_0-auc:0.71700
# [448]	validation_0-auc:0.71698
# [449]	validation_0-auc:0.71693
# [450]	validation_0-auc:0.71691
# [451]	validation_0-auc:0.71690
# [452]	validation_0-auc:0.71692
# [453]	validation_0-auc:0.71689
# [454]	validation_0-auc:0.71690
# [455]	validation_0-auc:0.71687
# [456]	validation_0-auc:0.71689
# [457]	validation_0-auc:0.71693
# [458]	validation_0-auc:0.71693
# [459]	validation_0-auc:0.71695
# [460]	validation_0-auc:0.71697
# [461]	validation_0-auc:0.71698
# [462]	validation_0-auc:0.71693
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.5, max_delta_step=0,
#               max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=700, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
fig, ax = plt.subplots()

plot_importance(xgb, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
xgb_pred = xgb.predict(x_test)
roc_score = roc_auc_score(y_test, xgb_pred)

print(f'roc_score: {round(roc_score*100,2)}%')
# Out:
# roc_score: 65.37%
