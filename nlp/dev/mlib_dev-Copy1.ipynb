# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (21.2.4)
# Collecting pip
#   Downloading pip-21.3.1-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 11.5 MB/s eta 0:00:01     |███████▋                        | 409 kB 11.5 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# Successfully installed pip-21.3.1

# %%
# !git clone https://github.com/entelecheia/eKoNLPy.git
# !pip install ./eKoNLPy
# Out:
# Cloning into 'eKoNLPy'...
# remote: Enumerating objects: 3590, done.
# remote: Total 3590 (delta 0), reused 0 (delta 0), pack-reused 3590
# Receiving objects: 100% (3590/3590), 73.30 MiB | 22.05 MiB/s, done.
# Resolving deltas: 100% (2618/2618), done.
# Processing ./eKoNLPy
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: konlpy>=0.4.4 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from eKoNLPy==0.5.30) (0.5.2)
# Requirement already satisfied: nltk>=2.0 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from eKoNLPy==0.5.30) (3.5)
# Requirement already satisfied: gensim>=3.1.0 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from eKoNLPy==0.5.30) (4.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from eKoNLPy==0.5.30) (1.5.2)
# Requirement already satisfied: numpy>=1.13 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from eKoNLPy==0.5.30) (1.18.5)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from gensim>=3.1.0->eKoNLPy==0.5.30) (5.2.1)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from konlpy>=0.4.4->eKoNLPy==0.5.30) (4.6.0)
# Requirement already satisfied: colorama in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from konlpy>=0.4.4->eKoNLPy==0.5.30) (0.4.4)
# Requirement already satisfied: lxml>=4.1.0 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from konlpy>=0.4.4->eKoNLPy==0.5.30) (4.6.1)
# Requirement already satisfied: JPype1>=0.7.0 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from konlpy>=0.4.4->eKoNLPy==0.5.30) (1.3.0)
# Requirement already satisfied: tweepy>=3.7.0 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from konlpy>=0.4.4->eKoNLPy==0.5.30) (3.10.0)
# Requirement already satisfied: regex in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from nltk>=2.0->eKoNLPy==0.5.30) (2020.10.15)
# Requirement already satisfied: tqdm in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from nltk>=2.0->eKoNLPy==0.5.30) (4.50.2)
# Requirement already satisfied: joblib in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from nltk>=2.0->eKoNLPy==0.5.30) (0.17.0)
# Requirement already satisfied: click in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from nltk>=2.0->eKoNLPy==0.5.30) (7.1.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from tweepy>=3.7.0->konlpy>=0.4.4->eKoNLPy==0.5.30) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from tweepy>=3.7.0->konlpy>=0.4.4->eKoNLPy==0.5.30) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from tweepy>=3.7.0->konlpy>=0.4.4->eKoNLPy==0.5.30) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy>=0.4.4->eKoNLPy==0.5.30) (3.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy>=0.4.4->eKoNLPy==0.5.30) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy>=0.4.4->eKoNLPy==0.5.30) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy>=0.4.4->eKoNLPy==0.5.30) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy>=0.4.4->eKoNLPy==0.5.30) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/yoo/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy>=0.4.4->eKoNLPy==0.5.30) (1.7.1)
# Building wheels for collected packages: eKoNLPy
#   Building wheel for eKoNLPy (setup.py) ... done
#   Created wheel for eKoNLPy: filename=eKoNLPy-0.5.30-py3-none-any.whl size=14437139 sha256=4cc0a0e9af1fcfb2baed3e96a77be66e0db6290f372a95ea1fa3fe43706e7087
#   Stored in directory: /private/var/folders/gl/xtlj588j4rdcnbyxmk7bz7jh0000gn/T/pip-ephem-wheel-cache-bydrd52s/wheels/30/5d/21/5e3477821d517803b47b1d16bad9d8fd9730b02eab5d3fee81
# Successfully built eKoNLPy
# Installing collected packages: eKoNLPy
#   Attempting uninstall: eKoNLPy
#     Found existing installation: eKoNLPy 0.5.30
#     Uninstalling eKoNLPy-0.5.30:
#       Successfully uninstalled eKoNLPy-0.5.30
# Successfully installed eKoNLPy-0.5.30
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/yoo/opt/anaconda3/bin/python3 -m pip install --upgrade pip' command.

# %%
# %%time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from tqdm import tqdm

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
# Out:
# CPU times: user 21 µs, sys: 0 ns, total: 21 µs
# Wall time: 24.8 µs

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
article_comp = pd.read_csv('/Users/yoo/Data-dev/nlp/dev/test_.csv')
article_comp.columns = ['created_date','article','price','label','token']
article_comp = article_comp[['created_date', 'article', 'token']]
article_comp
# Out:
#     created_date                                            article  \
# 0     2018-04-19                    도자료는     도자료는 으로           도자료는
# 1     2018-04-20                                      도자료는 으로
# 2     2018-04-24                    도자료는     도자료는     도자료는 으로
# 3     2018-04-25                                               도자료는
# 4     2018-04-26                                      도자료는 으로
# ..           ...                                                ...
# 452   2021-03-03   지난 일 오름 에도 불구하고 비트코인은  말 동안 손실분을 메우기 위해 고군분투하...
# 453   2021-03-04   블록체인 기반 웹 브라우저 브레이브가 자체 검색엔진을 개발한다 이를 위해 브레이브...
# 454   2021-03-08   게임회사 위메이드의 블록체인 계열회사 위메이드트리가 대체불가능토큰 시장에 진출한다...
# 455   2021-03-09   미국프로농구 댈러스 매버릭스 구단 이자 억만장자 기업가인 마크 큐반이 지난 일 도...
# 456   2021-03-10   인스타그램에서 비슷한 수법의 암호화폐 사기로 매달 수만달러의 자금이 도난당하고 있...
#
#                                                  token
# 0    [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '으로/MA...
# 1                      [['도/NNG', '자료/NNG', '으로/NNG']]
# 2    [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '도/NNG...
# 3                                [['도/NNG', '자료/NNG']]
# 4                      [['도/NNG', '자료/NNG', '으로/NNG']]
# ..                                                 ...
# 452  [['오름/NNG', '불구/NNG', '비트코인/NNG', '손실/NNG', '메...
# 453  [['블록체인/NNG', '개발/NNG', '하/VV', '위하/VV', '개방형/...
# 454  [['블록체인/NNG', '계열회사/NNG', '트리/NNG', '대체/MAG', ...
# 455  [['프로/NNG', '농구/NNG', '구단/NNG', '이자/NNG', '억만장...
# 456  [['인스타그램/NNG', '비슷/NNG', '수법/NNG', '암호화폐/NNG',...
#
# [457 rows x 3 columns]

# %%
price = pd.read_csv('/Users/yoo/Data-dev/nlp/dev/price.csv')
price
# Out:
#       trade_date          price   before_price   label
# 0     2018-03-15  9010234.20891            nan     nan
# 1     2018-03-16  9024833.95469  9010234.20891 1.00000
# 2     2018-03-17  9056906.80354  9024833.95469 1.00000
# 3     2018-03-18  8470860.29412  9056906.80354 0.00000
# 4     2018-03-19  8970286.25831  8470860.29412 1.00000
# ...          ...            ...            ...     ...
# 1318  2021-10-23 74501866.23316 76632600.67319 0.00000
# 1319  2021-10-24 74478050.59524 74501866.23316 0.00000
# 1320  2021-10-25 75178560.00732 74478050.59524 1.00000
# 1321  2021-10-26 75581706.19076 75178560.00732 1.00000
# 1322  2021-10-27 72994468.79360 75581706.19076 0.00000
#
# [1323 rows x 4 columns]

# %%
article = article_comp.set_index('created_date')
price = price.set_index('trade_date')

df_con = pd.concat([article, price], axis=1).dropna()
df_con = df_con[['article', 'price', 'label', 'token']]

df_con
# Out:
#                                                       article          price  \
# 2018-04-19                    도자료는     도자료는 으로           도자료는  8754047.24105
# 2018-04-20                                      도자료는 으로        9020520.71192
# 2018-04-24                    도자료는     도자료는     도자료는 으로        9980132.11203
# 2018-04-25                                               도자료는 10290519.14234
# 2018-04-26                                      도자료는 으로        9799738.52757
# ...                                                       ...            ...
# 2021-03-03   지난 일 오름 에도 불구하고 비트코인은  말 동안 손실분을 메우기 위해 고군분투하... 56740992.17798
# 2021-03-04   블록체인 기반 웹 브라우저 브레이브가 자체 검색엔진을 개발한다 이를 위해 브레이브... 57341344.23252
# 2021-03-08   게임회사 위메이드의 블록체인 계열회사 위메이드트리가 대체불가능토큰 시장에 진출한다... 57765992.83854
# 2021-03-09   미국프로농구 댈러스 매버릭스 구단 이자 억만장자 기업가인 마크 큐반이 지난 일 도... 60430299.86229
# 2021-03-10   인스타그램에서 비슷한 수법의 암호화폐 사기로 매달 수만달러의 자금이 도난당하고 있... 62622616.62071
#
#              label                                              token
# 2018-04-19 1.00000  [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '으로/MA...
# 2018-04-20 1.00000                    [['도/NNG', '자료/NNG', '으로/NNG']]
# 2018-04-24 1.00000  [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '도/NNG...
# 2018-04-25 1.00000                              [['도/NNG', '자료/NNG']]
# 2018-04-26 0.00000                    [['도/NNG', '자료/NNG', '으로/NNG']]
# ...            ...                                                ...
# 2021-03-03 1.00000  [['오름/NNG', '불구/NNG', '비트코인/NNG', '손실/NNG', '메...
# 2021-03-04 1.00000  [['블록체인/NNG', '개발/NNG', '하/VV', '위하/VV', '개방형/...
# 2021-03-08 1.00000  [['블록체인/NNG', '계열회사/NNG', '트리/NNG', '대체/MAG', ...
# 2021-03-09 1.00000  [['프로/NNG', '농구/NNG', '구단/NNG', '이자/NNG', '억만장...
# 2021-03-10 1.00000  [['인스타그램/NNG', '비슷/NNG', '수법/NNG', '암호화폐/NNG',...
#
# [457 rows x 4 columns]

# %%
df_con['article']
# Out:
# 2018-04-19                      도자료는     도자료는 으로           도자료는
# 2018-04-20                                        도자료는 으로
# 2018-04-24                      도자료는     도자료는     도자료는 으로
# 2018-04-25                                                 도자료는
# 2018-04-26                                        도자료는 으로
#                                     ...
# 2021-03-03     지난 일 오름 에도 불구하고 비트코인은  말 동안 손실분을 메우기 위해 고군분투하...
# 2021-03-04     블록체인 기반 웹 브라우저 브레이브가 자체 검색엔진을 개발한다 이를 위해 브레이브...
# 2021-03-08     게임회사 위메이드의 블록체인 계열회사 위메이드트리가 대체불가능토큰 시장에 진출한다...
# 2021-03-09     미국프로농구 댈러스 매버릭스 구단 이자 억만장자 기업가인 마크 큐반이 지난 일 도...
# 2021-03-10     인스타그램에서 비슷한 수법의 암호화폐 사기로 매달 수만달러의 자금이 도난당하고 있...
# Name: article, Length: 457, dtype: object

# %%
df_con['article'] = df_con['article'].apply(lambda x: x.split(' '))
df_con
# Out:
#                                                       article          price  \
# 2018-04-19  [, , , , , 도자료는, , , , , 도자료는, 으로, , , , , , ,...  8754047.24105
# 2018-04-20                   [, , , , , 도자료는, 으로, , , , , , ]  9020520.71192
# 2018-04-24  [, , , , , 도자료는, , , , , 도자료는, , , , , 도자료는, 으...  9980132.11203
# 2018-04-25                                   [, , , , , 도자료는] 10290519.14234
# 2018-04-26                   [, , , , , 도자료는, 으로, , , , , , ]  9799738.52757
# ...                                                       ...            ...
# 2021-03-03  [, 지난, 일, 오름, 에도, 불구하고, 비트코인은, , 말, 동안, 손실분을, ... 56740992.17798
# 2021-03-04  [, 블록체인, 기반, 웹, 브라우저, 브레이브가, 자체, 검색엔진을, 개발한다, ... 57341344.23252
# 2021-03-08  [, 게임회사, 위메이드의, 블록체인, 계열회사, 위메이드트리가, 대체불가능토큰, ... 57765992.83854
# 2021-03-09  [, 미국프로농구, 댈러스, 매버릭스, 구단, 이자, 억만장자, 기업가인, 마크, ... 60430299.86229
# 2021-03-10  [, 인스타그램에서, 비슷한, 수법의, 암호화폐, 사기로, 매달, 수만달러의, 자금... 62622616.62071
#
#              label                                              token
# 2018-04-19 1.00000  [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '으로/MA...
# 2018-04-20 1.00000                    [['도/NNG', '자료/NNG', '으로/NNG']]
# 2018-04-24 1.00000  [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '도/NNG...
# 2018-04-25 1.00000                              [['도/NNG', '자료/NNG']]
# 2018-04-26 0.00000                    [['도/NNG', '자료/NNG', '으로/NNG']]
# ...            ...                                                ...
# 2021-03-03 1.00000  [['오름/NNG', '불구/NNG', '비트코인/NNG', '손실/NNG', '메...
# 2021-03-04 1.00000  [['블록체인/NNG', '개발/NNG', '하/VV', '위하/VV', '개방형/...
# 2021-03-08 1.00000  [['블록체인/NNG', '계열회사/NNG', '트리/NNG', '대체/MAG', ...
# 2021-03-09 1.00000  [['프로/NNG', '농구/NNG', '구단/NNG', '이자/NNG', '억만장...
# 2021-03-10 1.00000  [['인스타그램/NNG', '비슷/NNG', '수법/NNG', '암호화폐/NNG',...
#
# [457 rows x 4 columns]

# %%
# def corpus_maker(raw_data):
#   # total count/ up count/ down count
#   corpus = defaultdict(lambda : [0,0,0])
#   for idx, token_book in tqdm(enumerate(raw_data['article'])):
    
#       for token in token_book:
#           if raw_data.iloc[idx].label==1:
#               corpus[token][0]+=1
#               corpus[token][1]+=1
#           elif raw_data.iloc[idx].label==0:
#               corpus[token][0]+=1
#               corpus[token][2]+=1
#           else:
#               corpus[token][0]+=1
            
#   return corpus

# %%
crypto_dict = corpus_maker(df_con)
crypto_dict_df = pd.DataFrame(crypto_dict).T

crypto_dict_df.columns = ['total', 'up', 'down']
crypto_dict_df
# Out:
# 457it [02:38,  2.89it/s]
#      total      up   down
#     224836  140916  83920
# 도     5840    3670   2170
# 자     8707    5476   3231
# 료     1658     971    687
# 는    15042    9324   5718
# ..     ...     ...    ...
# 셤        2       2      0
# 곁        1       0      1
# 낚        2       2      0
# 귬        2       2      0
# 춥        3       3      0
#
# [1256 rows x 3 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Corp Dic Checkpoint

# %%
# crypto_dict_df.to_csv('corp_dic_comp.csv')

# %%
corp_dic_comp = pd.read_csv('/Users/yoo/Data-dev/nlp/dev/corp_dic_comp.csv')
corp_dic_comp = corp_dic_comp.dropna()
corp_dic_comp
# Out:
#           Unnamed: 0  total  up  down
# 0      비용/NNG;부담/NNG      1   0     1
# 1       유동성/NNG;높/VV      1   0     1
# 2        가격/NNG;낮/VA      1   0     1
# 3            법무부/NNG     35  12    23
# 4             소속/NNG     23  13    10
# ...              ...    ...  ..   ...
# 11517         몬드/NNG      1   1     0
# 11518         퍼트/NNG      1   1     0
# 11519   좋/VA;고평가/NNG      1   0     1
# 11520       차익실현/NNG      1   0     1
# 11521         약진/NNG      1   0     1
#
# [11522 rows x 4 columns]

# %%
corp_dic_comp.sort_values(by='total',ascending=False)
# Out:
#       Unnamed: 0  total    up  down
# 18          하/VV   9862  5821  4041
# 63          되/VV   3316  1953  1363
# 12      암호화폐/NNG   2726  1693  1033
# 29      비트코인/NNG   2479  1535   944
# 157         있/VV   2391  1331  1060
# ...          ...    ...   ...   ...
# 7074       달궜/VV      1     0     1
# 7073      원대/NNG      1     0     1
# 7072     연저점/NNG      1     0     1
# 7070     사라져서/VV      1     0     1
# 11521     약진/NNG      1     0     1
#
# [11522 rows x 4 columns]

# %%
corp_dic_comp[['total']].describe()
# Out:
#              total
# count 11522.000000
# mean     15.913557
# std     122.048013
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       7.000000
# max    9862.000000

# %%
corp_dic = corp_dic_comp[corp_dic_comp['total'] > 10].sort_values(by='total', ascending=False)
corp_dic = corp_dic.set_index('Unnamed: 0')
corp_dic
# Out:
#             total    up  down
# Unnamed: 0
# 하/VV         9862  5821  4041
# 되/VV         3316  1953  1363
# 암호화폐/NNG     2726  1693  1033
# 비트코인/NNG     2479  1535   944
# 있/VV         2391  1331  1060
# ...           ...   ...   ...
# 파/VV           11     6     5
# 정전/NNG         11    11     0
# 로스트/NNG        11     4     7
# 대폭/MAG         11     3     8
# 민감/NNG         11     6     5
#
# [2106 rows x 3 columns]

# %%
corp_dic['tone_score']=((corp_dic['up']/corp_dic['total'])/(corp_dic['up'].sum()/corp_dic['total'].sum()))/((corp_dic['down']/corp_dic['total'])/(corp_dic['down'].sum()/corp_dic['total'].sum()))
corp_dic
# Out:
#             total    up  down  tone_score
# Unnamed: 0
# 하/VV         9862  5821  4041    1.045797
# 되/VV         3316  1953  1363    1.040267
# 암호화폐/NNG     2726  1693  1033    1.189858
# 비트코인/NNG     2479  1535   944    1.180524
# 있/VV         2391  1331  1060    0.911614
# ...           ...   ...   ...         ...
# 파/VV           11     6     5    0.871204
# 정전/NNG         11    11     0         inf
# 로스트/NNG        11     4     7    0.414859
# 대폭/MAG         11     3     8    0.272251
# 민감/NNG         11     6     5    0.871204
#
# [2106 rows x 4 columns]

# %%
corp_dic.describe()
# Out:
#             total          up        down  tone_score
# count 2106.000000 2106.000000 2106.000000 2106.000000
# mean    75.888414   43.967711   31.920703         inf
# std    277.670726  163.272920  114.899571         nan
# min     11.000000    0.000000    0.000000    0.000000
# 25%     16.000000   10.000000    7.000000    0.726003
# 50%     27.000000   16.000000   12.000000    1.016405
# 75%     61.750000   36.000000   26.000000    1.452007
# max   9862.000000 5821.000000 4041.000000         inf

# %%
# %%time
corp_dic['polarity'] = ''

for idx, value in tqdm(enumerate(corp_dic['tone_score'])):
    
  if corp_dic.iloc[idx].total >15:
    if value >= 1:
      corp_dic['polarity'][idx]='positive'
    elif value < 1:
      corp_dic['polarity'][idx]='negative'
    else:
      corp_dic['polarity'][idx]='nothing'
# Out:
# 0it [00:00, ?it/s]<timed exec>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2106it [00:00, 3872.68it/s]
# CPU times: user 530 ms, sys: 27.8 ms, total: 558 ms
# Wall time: 547 ms

# %%
corp_dic
# Out:
#             total    up  down  tone_score  polarity
# Unnamed: 0
# 하/VV         9862  5821  4041    1.045797  positive
# 되/VV         3316  1953  1363    1.040267  positive
# 암호화폐/NNG     2726  1693  1033    1.189858  positive
# 비트코인/NNG     2479  1535   944    1.180524  positive
# 있/VV         2391  1331  1060    0.911614  negative
# ...           ...   ...   ...         ...       ...
# 파/VV           11     6     5    0.871204
# 정전/NNG         11    11     0         inf
# 로스트/NNG        11     4     7    0.414859
# 대폭/MAG         11     3     8    0.272251
# 민감/NNG         11     6     5    0.871204
#
# [2106 rows x 5 columns]

# %%
pos_dic = corp_dic[corp_dic['polarity'] == 'positive'].sort_values(by='tone_score',ascending=False)
neg_dic = corp_dic[corp_dic['polarity'] == 'negative'].sort_values(by='tone_score',ascending=False)

# %%
pos_list = pos_dic.reset_index(inplace=False)
pos_list.columns = ['positive', 'total', 'up', 'down', 'tone_score', 'polarity']
pos_list = list(pos_list['positive'])

# %%
neg_list = neg_dic.reset_index(inplace=False)
neg_list.columns = ['negative', 'total', 'up', 'down', 'tone_score', 'polarity']
neg_list = list(neg_list['negative'])

# %%
crypto_dic = corp_dic[['tone_score','polarity']]
crypto_dic
# Out:
#             tone_score  polarity
# Unnamed: 0
# 하/VV          1.045797  positive
# 되/VV          1.040267  positive
# 암호화폐/NNG      1.189858  positive
# 비트코인/NNG      1.180524  positive
# 있/VV          0.911614  negative
# ...                ...       ...
# 파/VV          0.871204
# 정전/NNG             inf
# 로스트/NNG       0.414859
# 대폭/MAG        0.272251
# 민감/NNG        0.871204
#
# [2106 rows x 2 columns]

# %%
temp = crypto_dic.reset_index()
temp.columns = ['corpus','tone_score','polarity']
temp[['corpus','tone_score']]
# Out:
#         corpus  tone_score
# 0         하/VV    1.045797
# 1         되/VV    1.040267
# 2     암호화폐/NNG    1.189858
# 3     비트코인/NNG    1.180524
# 4         있/VV    0.911614
# ...        ...         ...
# 2101      파/VV    0.871204
# 2102    정전/NNG         inf
# 2103   로스트/NNG    0.414859
# 2104    대폭/MAG    0.272251
# 2105    민감/NNG    0.871204
#
# [2106 rows x 2 columns]

# %%
temp = temp[['corpus', 'tone_score']]
crypto_list = list(temp['corpus'])
crypto_score = list(temp['tone_score'])

# %% [markdown]
# ---

# %% [markdown]
# ---
# ---

# %%
test_ = pd.read_csv('/Users/yoo/Data-dev/nlp/dev/test_.csv')
test_.columns = ['created_date', 'article', 'price', 'label', 'token']
test = test_
test
# Out:
#     created_date                                            article  \
# 0     2018-04-19                    도자료는     도자료는 으로           도자료는
# 1     2018-04-20                                      도자료는 으로
# 2     2018-04-24                    도자료는     도자료는     도자료는 으로
# 3     2018-04-25                                               도자료는
# 4     2018-04-26                                      도자료는 으로
# ..           ...                                                ...
# 452   2021-03-03   지난 일 오름 에도 불구하고 비트코인은  말 동안 손실분을 메우기 위해 고군분투하...
# 453   2021-03-04   블록체인 기반 웹 브라우저 브레이브가 자체 검색엔진을 개발한다 이를 위해 브레이브...
# 454   2021-03-08   게임회사 위메이드의 블록체인 계열회사 위메이드트리가 대체불가능토큰 시장에 진출한다...
# 455   2021-03-09   미국프로농구 댈러스 매버릭스 구단 이자 억만장자 기업가인 마크 큐반이 지난 일 도...
# 456   2021-03-10   인스타그램에서 비슷한 수법의 암호화폐 사기로 매달 수만달러의 자금이 도난당하고 있...
#
#              price   label                                              token
# 0    8754047.24105 1.00000  [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '으로/MA...
# 1    9020520.71192 1.00000                    [['도/NNG', '자료/NNG', '으로/NNG']]
# 2    9980132.11203 1.00000  [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '도/NNG...
# 3   10290519.14234 1.00000                              [['도/NNG', '자료/NNG']]
# 4    9799738.52757 0.00000                    [['도/NNG', '자료/NNG', '으로/NNG']]
# ..             ...     ...                                                ...
# 452 56740992.17798 1.00000  [['오름/NNG', '불구/NNG', '비트코인/NNG', '손실/NNG', '메...
# 453 57341344.23252 1.00000  [['블록체인/NNG', '개발/NNG', '하/VV', '위하/VV', '개방형/...
# 454 57765992.83854 1.00000  [['블록체인/NNG', '계열회사/NNG', '트리/NNG', '대체/MAG', ...
# 455 60430299.86229 1.00000  [['프로/NNG', '농구/NNG', '구단/NNG', '이자/NNG', '억만장...
# 456 62622616.62071 1.00000  [['인스타그램/NNG', '비슷/NNG', '수법/NNG', '암호화폐/NNG',...
#
# [457 rows x 5 columns]

# %%
# %%time
word_score = []

for pair in zip(crypto_list, crypto_score):
    pair = list(pair)
    word_score.append(pair)
    
word_score[:5]
# Out:
# CPU times: user 1.02 ms, sys: 13 µs, total: 1.03 ms
# Wall time: 1.05 ms
# [['하/VV', 0.9723297058704427],
#  ['되/VV', 1.00426441836254],
#  ['있/VV', 0.9464726401218899],
#  ['암호화폐/NNG', 1.1427824468010246],
#  ['다/MAG', 1.0433342655647961]]

# %%
article_word = []

for i in test['token']:
    q = i.replace('"','').replace('[[','').replace(']]','').split(', ')
    article_word.append(q)

article_word[0][0]
# Out:
# "'도/NNG'"

# %%
# article_word = test['token']
tmp = []

for i in tqdm(article_word):
    ar = [[],[]]
    ar[0].append(i)
    
    for j in i:
        
        if j[1:-1] in list(corp_dic.index):
            ar[1].append(word_score[[_[0] for _ in word_score].index(j[1:-1])][1])
    
    tmp.append(ar)
            
len(tmp)
# Out:
# 100%|██████████| 457/457 [00:31<00:00, 14.31it/s]
# 457

# %%
pd.DataFrame(tmp)
# Out:
#                                                      0  \
# 0    [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '으로/MA...
# 1                      [['도/NNG', '자료/NNG', '으로/NNG']]
# 2    [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '도/NNG...
# 3                                [['도/NNG', '자료/NNG']]
# 4                      [['도/NNG', '자료/NNG', '으로/NNG']]
# ..                                                 ...
# 452  [['오름/NNG', '불구/NNG', '비트코인/NNG', '손실/NNG', '메...
# 453  [['블록체인/NNG', '개발/NNG', '하/VV', '위하/VV', '개방형/...
# 454  [['블록체인/NNG', '계열회사/NNG', '트리/NNG', '대체/MAG', ...
# 455  [['프로/NNG', '농구/NNG', '구단/NNG', '이자/NNG', '억만장...
# 456  [['인스타그램/NNG', '비슷/NNG', '수법/NNG', '암호화폐/NNG',...
#
#                                                      1
# 0    [0.8184082647397646, 0.7713484752104514, 0.818...
# 1    [0.8184082647397646, 0.7713484752104514, 0.719...
# 2    [0.8184082647397646, 0.7713484752104514, 0.818...
# 3             [0.8184082647397646, 0.7713484752104514]
# 4    [0.8184082647397646, 0.7713484752104514, 0.719...
# ..                                                 ...
# 452  [0.799125567115537, 1.2043963904384163, 0.8172...
# 453  [0.8227930490684361, 0.805874938459418, 0.9723...
# 454  [0.8227930490684361, 0.9829244475521104, 0.542...
# 455  [0.998906958894421, 0.654668253060036, 0.73765...
# 456  [1.4863735548348986, 1.6781636909426274, 1.142...
#
# [457 rows x 2 columns]

# %% [markdown]
# ---

# %%
## It just prod

# test = pd.read_csv('/Users/yoo/Data-dev/nlp/dev/article_token.csv')
# test
# Out:
#     created_date                                            article  \
# 0     2018-03-15   김동연 부총리 겸 기획재정부 장관은 가상통화에  금을 매기는 게 바람직한지 논의 ...
# 1     2018-03-16   라인의 금융 자회사 라인 파이낸셜 통해 일본 금융청에 가상화폐 거래 사업자 신청 ...
# 2     2018-03-19   콘텐츠 생산자와 추천인에게  상 는 이용자 정 로 부 독점 페이스북 등에 반기 작...
# 3     2018-03-29       도자료는 당신이 풀 노드로 돌리고 있는 블록체인에 아동 포르노가 연결되어 ...
# 4     2018-04-03                                      도자료는 으로
# ..           ...                                                ...
# 605   2021-10-21    신고점 경신한 비트코인  말엔 리스크 관리 우선해야 비트코인은 지난 일 밤 시경...
# 606   2021-10-22   일 금융위원회 위원장 고승범 는 지난 월 일 가상자산 사업자 신고 마감 이후 먹튀...
# 607   2021-10-25   조정의 끝을 알고 싶다면 만 달러 지지해야 비트코인은 일 오후 시경 만 달러 선까...
# 608   2021-10-26   미국 증권 금융의 최고 규  기구인 증권거래위원회 가 억 달러 규모의 스테이블 코...
# 609   2021-10-27    가상자산 데이터 분석 업체 글래스노드가 일 스위스 시간  간 온체인  고서 를 ...
#
#                                                  token
# 0    [['가상화폐/NNG', '금/NNG', '매기/VV', '바람직/NNG', '논의...
# 1    [['라인/NNG', '금융/NNG', '자회사/NNG', '라인/NNG', '파이...
# 2    [['생산자/NNG', '추천인/NNG', '상/NNG', '부/NNG', '독점/...
# 3    [['도/NNG', '자료/NNG', '풀/VV', '노드/NNG', '돌리/VV'...
# 4                      [['도/NNG', '자료/NNG', '으로/NNG']]
# ..                                                 ...
# 605  [['신고점/NNG', '경신/NNG', '하/VV', '비트코인/NNG', '엔/...
# 606  [['가상/NNG', '자산/NNG', '사업자/NNG', '신고/NNG', '마감...
# 607  [['조정/NNG', '끝/NNG', '알/VV', '달러/NNG', '지지/NNG...
# 608  [['증권금융/NNG', '최고/NNG', '규/NNG', '기구/NNG', '증권...
# 609  [['가상/NNG', '자산/NNG', '데이터/NNG', '분석/NNG', '업체...
#
# [610 rows x 3 columns]

# %%
# %%time
word_score = []

for pair in zip(crypto_list, crypto_score):
    pair = list(pair)
    word_score.append(pair)
    
word_score[:5]
# Out:
# CPU times: user 1.66 ms, sys: 98 µs, total: 1.75 ms
# Wall time: 1.86 ms
# [['하/VV', 0.9723297058704427],
#  ['되/VV', 1.00426441836254],
#  ['있/VV', 0.9464726401218899],
#  ['암호화폐/NNG', 1.1427824468010246],
#  ['다/MAG', 1.0433342655647961]]

# %%
# 이런 양식으로 가야함..
temp[0].replace('[[','').replace(']]','').split(',')[0]
# Out:
# "'가상화폐/NNG'"

# %%
print(crypto_list[:5])
print(word_score[:5])
# Out:
# ['하/VV', '되/VV', '있/VV', '암호화폐/NNG', '다/MAG']
# [['하/VV', 0.9723297058704427], ['되/VV', 1.00426441836254], ['있/VV', 0.9464726401218899], ['암호화폐/NNG', 1.1427824468010246], ['다/MAG', 1.0433342655647961]]

# %%
# %%time

tmp = []

for i in range(len(test['token'])):
    t = test['token'][i].replace('"','').replace('[[','').replace(']]','').split(', ')
    tmp.append(t)
# Out:
# CPU times: user 32.7 ms, sys: 9.41 ms, total: 42.1 ms
# Wall time: 42.1 ms

# %%
# tmp[][] == '라인/NNG'
# len(tmp[]) = 610
# len(tmp[][]) = 2210, 1850, ...

# %%
# %%time

tmp_score = []

for t in range(len(tmp)):
    for j in range(len(tmp[t])):
        
        if tmp[i][j] in [_[0] for _ in word_score]:
            tmp_score.append(_[1] for _ in word_score)
            
tmp_score[:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# TypeError: list indices must be integers or slices, not list

# %%
tmp = [[], []]

for i in test['token'][4].replace('[[','').replace(']]','').split(', '):
    tmp.append(i)
    
tmp
# Out:
# [[], [], "'도/NNG'", "'자료/NNG'", "'으로/NNG'"]

# %% [markdown]
# ---

# %%
word_score[:5]
# Out:
# [['하/VV', 1.0296973160782181],
#  ['되/VV', 1.0135478070306678],
#  ['암호화폐/NNG', 1.1669143125700256],
#  ['있/VV', 0.8726733844288121],
#  ['비트코인/NNG', 1.1555047783378518]]

# %%
# %%time
# Calculating tone score

score_list = []

for i in tqdm(range(len(test)), desc='Finding token'):
    for sentence in test['token'][i].replace('[[','').replace(']]','').split(', '):
        score_list.append(sentence)
        
score_list
# Out:
# Finding token: 100%|██████████| 610/610 [00:00<00:00, 6333.85it/s]
# CPU times: user 82.5 ms, sys: 16 ms, total: 98.5 ms
# Wall time: 99.1 ms
# ["'가상화폐/NNG'",
#  "'금/NNG'",
#  "'매기/VV'",
#  "'바람직/NNG'",
#  "'논의/NNG'",
#  "'중/NNG'",
#  "'기술/NNG'",
#  "'발전/NNG'",
#  "'가로막/VV'",
#  "'않/VX'",
#  "'대책/NNG'",
#  "'마련/NNG'",
#  "'하/VV'",
#  "'밝히/VV'",
#  "'실/NNG'",
#  "'중심/NNG'",
#  "'민관/NNG'",
#  "'태스크포스/NNG'",
#  "'구성/NNG'",
#  "'열/VV'",
#  "'각국/NNG'",
#  "'사례/NNG'",
#  "'살/VV'",
#  "'펴/VV'",
#  "'종/NNG'",
#  "'청사/NNG'",
#  "'송년/NNG'",
#  "'열/VV'",
#  "'가상화폐/NNG'",
#  "'다수/NNG'",
#  "'국가/NNG'",
#  "'양도소득/NNG'",
#  "'방향/NNG'",
#  "'채택/NNG'",
#  "'하/VV'",
#  "'안다/VV'",
#  "'사업소득/NNG'",
#  "'법인/NNG'",
#  "'드물/VA'",
#  "'부가가치/NNG'",
#  "'적용/NNG'",
#  "'검토/NNG'",
#  "'하/XSV'",
#  "'고/NNG'",
#  "'밝히/VV'",
#  "'가상화폐/NNG'",
#  "'거래/NNG'",
#  "'현황/NNG'",
#  "'논의/NNG'",
#  "'중/NNG'",
#  "'기술/NNG'",
#  "'발전/NNG'",
#  "'가로막/VV'",
#  "'않/VX'"]

# %%
test
# Out:
#     created_date                                            article  \
# 0     2018-03-15   김동연 부총리 겸 기획재정부 장관은 가상통화에  금을 매기는 게 바람직한지 논의 ...
# 1     2018-03-16   라인의 금융 자회사 라인 파이낸셜 통해 일본 금융청에 가상화폐 거래 사업자 신청 ...
# 2     2018-03-19   콘텐츠 생산자와 추천인에게  상 는 이용자 정 로 부 독점 페이스북 등에 반기 작...
# 3     2018-03-29       도자료는 당신이 풀 노드로 돌리고 있는 블록체인에 아동 포르노가 연결되어 ...
# 4     2018-04-03                                      도자료는 으로
# ..           ...                                                ...
# 605   2021-10-21    신고점 경신한 비트코인  말엔 리스크 관리 우선해야 비트코인은 지난 일 밤 시경...
# 606   2021-10-22   일 금융위원회 위원장 고승범 는 지난 월 일 가상자산 사업자 신고 마감 이후 먹튀...
# 607   2021-10-25   조정의 끝을 알고 싶다면 만 달러 지지해야 비트코인은 일 오후 시경 만 달러 선까...
# 608   2021-10-26   미국 증권 금융의 최고 규  기구인 증권거래위원회 가 억 달러 규모의 스테이블 코...
# 609   2021-10-27    가상자산 데이터 분석 업체 글래스노드가 일 스위스 시간  간 온체인  고서 를 ...
#
#                                                  token
# 0    [['가상화폐/NNG', '금/NNG', '매기/VV', '바람직/NNG', '논의...
# 1    [['라인/NNG', '금융/NNG', '자회사/NNG', '라인/NNG', '파이...
# 2    [['생산자/NNG', '추천인/NNG', '상/NNG', '부/NNG', '독점/...
# 3    [['도/NNG', '자료/NNG', '풀/VV', '노드/NNG', '돌리/VV'...
# 4                      [['도/NNG', '자료/NNG', '으로/NNG']]
# ..                                                 ...
# 605  [['신고점/NNG', '경신/NNG', '하/VV', '비트코인/NNG', '엔/...
# 606  [['가상/NNG', '자산/NNG', '사업자/NNG', '신고/NNG', '마감...
# 607  [['조정/NNG', '끝/NNG', '알/VV', '달러/NNG', '지지/NNG...
# 608  [['증권금융/NNG', '최고/NNG', '규/NNG', '기구/NNG', '증권...
# 609  [['가상/NNG', '자산/NNG', '데이터/NNG', '분석/NNG', '업체...
#
# [610 rows x 3 columns]

# %%
article_word[0][0]
# Out:
# "'가상화폐/NNG'"

# %%
article_word = []

for i in test['token']:
    q = i.replace('"','').replace('[[','').replace(']]','').split(', ')
    article_word.append(q)

article_word[0][0]
# Out:
# "'도/NNG'"

# %%
list(corp_dic.index)
# Out:
# ['하/VV',
#  '되/VV',
#  '암호화폐/NNG',
#  '있/VV',
#  '비트코인/NNG',
#  '다/MAG',
#  '코인/NNG',
#  '도/NNG',
#  '달러/NNG',
#  '블록체인/NNG',
#  '자료/NNG',
#  '가격/NNG',
#  '거래소/NNG',
#  '거래/NNG',
#  '않/VX',
#  '자산/NNG',
#  '가/VV',
#  '시장/NNG',
#  '위하/VV',
#  '없/VA',
#  '서비스/NNG',
#  '더/MAG',
#  '받/VV',
#  '밝히/VV',
#  '토큰/NNG',
#  '통하/VV',
#  '중/NNG',
#  '투자/NNG',
#  '크/VA',
#  '규/NNG',
#  '기업/NNG',
#  '가상/NNG',
#  '국/NNG',
#  '아니/VCN',
#  '있/VA',
#  '기술/NNG',
#  '많/VA',
#  '비트/NNG',
#  '이더리움/NNG',
#  '같/VA',
#  '금융/NNG',
#  '따르/VV',
#  '정/NNG',
#  '오/VV',
#  '자금/NNG',
#  '은행/NNG',
#  '사람/NNG',
#  '상승/NNG',
#  '채굴/NNG',
#  '사용/NNG',
#  '문/NNG',
#  '때/NNG',
#  '데스크/NNG',
#  '프로젝트/NNG',
#  '공/NNG',
#  '시스템/NNG',
#  '결/NNG',
#  '법/NNG',
#  '업체/NNG',
#  '오르/VV',
#  '시작/NNG',
#  '데이터/NNG',
#  '개발/NNG',
#  '기관/NNG',
#  '높/VA',
#  '사업/NNG',
#  '화폐/NNG',
#  '이용/NNG',
#  '규모/NNG',
#  '안/MAG',
#  '운영/NNG',
#  '으로/MAG',
#  '가장/MAG',
#  '발행/NNG',
#  '개인/NNG',
#  '과/NNG',
#  '지갑/NNG',
#  '전/NNG',
#  '확인/NNG',
#  '시/NNG',
#  '중앙/NNG',
#  '설명/NNG',
#  '블/NNG',
#  '출시/NNG',
#  '발표/NNG',
#  '기준/NNG',
#  '고객/NNG',
#  '지원/NNG',
#  '생각/NNG',
#  '업/NNG',
#  '활용/NNG',
#  '가능/NNG',
#  '새롭/VA',
#  '하락/NNG',
#  '돈/NNG',
#  '업계/NNG',
#  '만들/VV',
#  '가능성/NNG',
#  '면/NNG',
#  '기록/NNG',
#  '를/NNG',
#  '스테이/NNG',
#  '공개/NNG',
#  '진행/NNG',
#  '점/NNG',
#  '계획/NNG',
#  '안/NNG',
#  '의/NNG',
#  '코로나/NNG',
#  '사업자/NNG',
#  '고/NNG',
#  '글로벌/NNG',
#  '또/MAG',
#  '발생/NNG',
#  '는/VV',
#  '로/NNG',
#  '장/NNG',
#  '참여/NNG',
#  '나오/VV',
#  '예정/NNG',
#  '필/NNG',
#  '금/NNG',
#  '상장/NNG',
#  '계/NNG',
#  '알/VV',
#  '이유/NNG',
#  '대해/VV',
#  '판매/NNG',
#  '관리/NNG',
#  '분석/NNG',
#  '넘/VV',
#  '위험/NNG',
#  '보/VV',
#  '늘/VV',
#  '산업/NNG',
#  '증가/NNG',
#  '인다/VV',
#  '으로/NNG',
#  '못하/VX',
#  '체인/NNG',
#  '어렵/VA',
#  '다양/NNG',
#  '신고/NNG',
#  '개/NNG',
#  '곳/NNG',
#  '사용자/NNG',
#  '경/NNG',
#  '포함/NNG',
#  '들/VV',
#  '아직/MAG',
#  '빗/NNG',
#  '관계자/NNG',
#  '국가/NNG',
#  '수준/NNG',
#  '함께/MAG',
#  '수수료/NNG',
#  '베이스/NNG',
#  '가지/VV',
#  '상/NNG',
#  '다시/MAG',
#  '모두/MAG',
#  '적용/NNG',
#  '위/NNG',
#  '지역/NNG',
#  '최대/NNG',
#  '추가/NNG',
#  '줄/VV',
#  '대상/NNG',
#  '수/NNG',
#  '이루/VV',
#  '대출/NNG',
#  '변동성/NNG',
#  '자신/NNG',
#  '의미/NNG',
#  '특히/MAG',
#  '이/VV',
#  '상품/NNG',
#  '고서/NNG',
#  '코/NNG',
#  '나타나/VV',
#  '수익/NNG',
#  '증권/NNG',
#  '영향/NNG',
#  '전망/NNG',
#  '사이/NNG',
#  '이미/MAG',
#  '특정/NNG',
#  '계정/NNG',
#  '썸/NNG',
#  '펀드/NNG',
#  '구축/NNG',
#  '관하/VV',
#  '계약/NNG',
#  '열/VV',
#  '결과/NNG',
#  '유지/NNG',
#  'fed/NNG',
#  '도입/NNG',
#  '용/NNG',
#  '엔/NNG',
#  '언급/NNG',
#  '사실/NNG',
#  '관심/NNG',
#  '인하/VV',
#  '과정/NNG',
#  '커뮤니티/NNG',
#  '선/NNG',
#  '성장/NNG',
#  '평가/NNG',
#  '매수/NNG',
#  '전하/VV',
#  '계좌/NNG',
#  '뒤/NNG',
#  '원/NNG',
#  '준비/NNG',
#  '블록/NNG',
#  '기대/NNG',
#  '트위터/NNG',
#  '정책/NNG',
#  '결정/NNG',
#  '사례/NNG',
#  '프로토콜/NNG',
#  '최고/NNG',
#  '소/NNG',
#  '부/NNG',
#  '빠르/VA',
#  '중단/NNG',
#  '매우/MAG',
#  '금지/NNG',
#  '통화/NNG',
#  '방지/NNG',
#  '실/NNG',
#  '좋/VA',
#  '가운데/NNG',
#  '이자/NNG',
#  '없이/MAG',
#  '비/NNG',
#  '신원/NNG',
#  '년/NNG',
#  '우려/NNG',
#  '쉽/VA',
#  '기/NNG',
#  '이용자/NNG',
#  '금리/NNG',
#  '생태계/NNG',
#  '직접/MAG',
#  '목표/NNG',
#  '배/NNG',
#  '혁신/NNG',
#  '예상/NNG',
#  '신뢰/NNG',
#  '이야기/NNG',
#  '잘/MAG',
#  '낮/VA',
#  '노드/NNG',
#  '공급/NNG',
#  '기능/NNG',
#  '지적/NNG',
#  '약/NNG',
#  '분야/NNG',
#  '대비/NNG',
#  '해결/NNG',
#  '탁/MAG',
#  '실명/NNG',
#  '개발자/NNG',
#  '내/VV',
#  '증명/NNG',
#  '지급/NNG',
#  '립/NNG',
#  '그룹/NNG',
#  '두/VV',
#  '인증/NNG',
#  '원화/NNG',
#  '범죄/NNG',
#  '유동성/NNG',
#  '떨어/VV',
#  '어떻게/MAG',
#  '이러/NNG',
#  '찾/VV',
#  '지속/NNG',
#  '쓰/VV',
#  '시행/NNG',
#  '암호/NNG',
#  '필/VV',
#  '처리/NNG',
#  '이전/NNG',
#  '식/NNG',
#  '시가총액/NNG',
#  '상태/NNG',
#  '얻/VV',
#  '판단/NNG',
#  '해외/NNG',
#  '현금/NNG',
#  '결국/MAG',
#  '강화/NNG',
#  '스왑/NNG',
#  '기사/NNG',
#  '추적/NNG',
#  '입장/NNG',
#  '이어지/VV',
#  '많이/MAG',
#  '장기/NNG',
#  '사회/NNG',
#  '바이/MAG',
#  '이렇게/MAG',
#  '불가능/NNG',
#  '해킹/NNG',
#  '법정/NNG',
#  '전략/NNG',
#  '사기/NNG',
#  '활동/NNG',
#  '규정/NNG',
#  '변화/NNG',
#  '미/NNG',
#  '스타트업/NNG',
#  '조사/NNG',
#  '핵심/NNG',
#  '나서/VV',
#  '목/NNG',
#  '여전히/MAG',
#  '그러/VV',
#  '작품/NNG',
#  '승인/NNG',
#  '형태/NNG',
#  '업무/NNG',
#  '공유/NNG',
#  '사건/NNG',
#  '마련/NNG',
#  '미래/NNG',
#  '비용/NNG',
#  '여부/NNG',
#  '급등/NNG',
#  '덧붙이/VV',
#  '매도/NNG',
#  '발전/NNG',
#  '소득/NNG',
#  '등록/NNG',
#  '설립/NNG',
#  '현상/NNG',
#  '행위/NNG',
#  '연구/NNG',
#  '의견/NNG',
#  '역할/NNG',
#  '인/NNG',
#  '신청/NNG',
#  '유하/VV',
#  '그렇/VA',
#  '해시/NNG',
#  '막/VV',
#  '송금/NNG',
#  '포인트/NNG',
#  '확대/NNG',
#  '존재/NNG',
#  '바이/NNG',
#  '스마트/NNG',
#  '소식/NNG',
#  '프로그램/NNG',
#  '재단/NNG',
#  '논의/NNG',
#  '불법/NNG',
#  '질문/NNG',
#  '비슷/NNG',
#  '절차/NNG',
#  '검증/NNG',
#  '조/NNG',
#  '비롯/NNG',
#  '자유/NNG',
#  '피해/NNG',
#  '도지/NNG',
#  '인프라/NNG',
#  '관계/NNG',
#  '바로/MAG',
#  '라인/NNG',
#  '국민/NNG',
#  '팀/NNG',
#  '당/NNG',
#  '추진/NNG',
#  '전환/NNG',
#  '반면/NNG',
#  '강조/NNG',
#  '링크/NNG',
#  '더욱/MAG',
#  '호/NNG',
#  '저장/NNG',
#  '인플레이션/NNG',
#  '이름/NNG',
#  '입출금/NNG',
#  '계속/NNG',
#  '예측/NNG',
#  '법률/NNG',
#  '확장/NNG',
#  '구매/NNG',
#  '개정/NNG',
#  '기회/NNG',
#  '중심/NNG',
#  '크/VV',
#  '협회/NNG',
#  '협력/NNG',
#  '작/VA',
#  '거버넌스/NNG',
#  '개당/NNG',
#  '확/MAG',
#  '거의/MAG',
#  '이해/NNG',
#  '팔/VV',
#  '같이/MAG',
#  '계속/MAG',
#  '가상화폐/NNG',
#  '방안/NNG',
#  '연동/NNG',
#  '사이트/NNG',
#  '소비자/NNG',
#  '인원/NNG',
#  '차/NNG',
#  '민간/NNG',
#  '환경/NNG',
#  '그리/MAG',
#  '앞서/VV',
#  '뜻/NNG',
#  '현지/NNG',
#  '조치/NNG',
#  '출금/NNG',
#  '전송/NNG',
#  '영업/NNG',
#  '담/VV',
#  '강/NNG',
#  '의무/NNG',
#  '인수/NNG',
#  '지표/NNG',
#  '경험/NNG',
#  '감소/NNG',
#  '지불/NNG',
#  '여/VV',
#  '성공/NNG',
#  '미치/VV',
#  '일어나/VV',
#  '엑스/NNG',
#  '카드/NNG',
#  '상당/NNG',
#  '지지/NNG',
#  '분산/NNG',
#  '속도/NNG',
#  '확산/NNG',
#  '실/VV',
#  '위안/NNG',
#  '수치/NNG',
#  '달/NNG',
#  '예/NNG',
#  '에서/NNG',
#  '각종/NNG',
#  '대응/NNG',
#  '발급/NNG',
#  '살/VV',
#  '효과/NNG',
#  '입금/NNG',
#  '였/VV',
#  '금융기관/NNG',
#  '대해서/VV',
#  '신규/NNG',
#  '파생상품/NNG',
#  '체계/NNG',
#  '뉴스/NNG',
#  '시행령/NNG',
#  '연방/NNG',
#  '전문/NNG',
#  '명/NNG',
#  '창업자/NNG',
#  '다르/VA',
#  '교환/NNG',
#  '캡/NNG',
#  '수탁/NNG',
#  '예치/NNG',
#  '법안/NNG',
#  '차지/NNG',
#  '물론/MAG',
#  '관/NNG',
#  '접근/NNG',
#  '종/NNG',
#  '유치/NNG',
#  '달리/MAG',
#  '구성/NNG',
#  '자사/NNG',
#  '만든/VV',
#  '맡/VV',
#  '높/VV',
#  '등장/NNG',
#  '혐의/NNG',
#  '코리아/NNG',
#  '대체/NNG',
#  '고려/NNG',
#  '노력/NNG',
#  '수사/NNG',
#  '청/NNG',
#  '익명/NNG',
#  '나무/NNG',
#  '모델/NNG',
#  '기자/NNG',
#  '더/NNG',
#  '목적/NNG',
#  '기본/NNG',
#  '페이팔/NNG',
#  '손실/NNG',
#  '지분/NNG',
#  '리플/NNG',
#  '가스/NNG',
#  '신호/NNG',
#  '개정안/NNG',
#  '구체적/VAX',
#  '맞/VV',
#  '검토/NNG',
#  '인식/NNG',
#  '굴기/NNG',
#  '종료/NNG',
#  '경쟁/NNG',
#  '대신/NNG',
#  '유명/NNG',
#  '달하/VV',
#  '지수/NNG',
#  '너무/MAG',
#  '널리/MAG',
#  '단기/NNG',
#  '바뀌/VV',
#  '스퀘어/NNG',
#  '시대/NNG',
#  '차트/NNG',
#  '돌파/NNG',
#  '아침/NNG',
#  '문서/NNG',
#  '뉴욕/NNG',
#  '회복/NNG',
#  '규칙/NNG',
#  '크/MAG',
#  '증권거래위원회/NNG',
#  '통/MAG',
#  '채/MAG',
#  '센터/NNG',
#  '날/NNG',
#  '좀/MAG',
#  '공격/NNG',
#  '이익/NNG',
#  '생산/NNG',
#  '선물/NNG',
#  '개념/NNG',
#  '부동산/NNG',
#  '유/NNG',
#  '공시/NNG',
#  '읽/VV',
#  '갭/NNG',
#  '잡/VV',
#  '집중/NNG',
#  '조직/NNG',
#  '위기/NNG',
#  '최초/NNG',
#  '캐피털/NNG',
#  '체결/NNG',
#  '대규모/NNG',
#  '정치/NNG',
#  '개선/NNG',
#  '대/NNG',
#  '티/NNG',
#  '글/NNG',
#  '나라/NNG',
#  '법인/NNG',
#  '더불/VV',
#  '훨씬/MAG',
#  '모르/VV',
#  '웹/NNG',
#  '풀/NNG',
#  '설계/NNG',
#  '수익률/NNG',
#  '프라이버시/NNG',
#  '금액/NNG',
#  '시도/NNG',
#  '컨소시엄/NNG',
#  '거치/VV',
#  '책임자/NNG',
#  '공지/NNG',
#  '구조/NNG',
#  '구입/NNG',
#  '채권/NNG',
#  '놓/VV',
#  '금융서비스/NNG',
#  '인정/NNG',
#  '논란/NNG',
#  '지정/NNG',
#  '출/VV',
#  '비해/VV',
#  '앞서/MAG',
#  '답/NNG',
#  '공식/NNG',
#  '앞두/VV',
#  '우선/MAG',
#  '테스트/NNG',
#  '투명/NNG',
#  '용은/NNG',
#  '현실/NNG',
#  '최소/NNG',
#  '프리미엄/NNG',
#  '매체/NNG',
#  '안전/NNG',
#  '방/NNG',
#  '믿/VV',
#  '품/NNG',
#  '오픈/NNG',
#  '성과/NNG',
#  '통과/NNG',
#  '리브/NNG',
#  '파트너/NNG',
#  '자동/NNG',
#  '사태/NNG',
#  '룰/NNG',
#  '이르/VV',
#  '비교/NNG',
#  '전통적/VAX',
#  '표준/NNG',
#  '머스크/NNG',
#  '예치금/NNG',
#  '역대/NNG',
#  '선택/NNG',
#  '범위/NNG',
#  '벌/VV',
#  '금융시장/NNG',
#  '온/VV',
#  '얘기/NNG',
#  '을/NNG',
#  '트/NNG',
#  '역/NNG',
#  '유사/NNG',
#  '소개/NNG',
#  '가량/NNG',
#  '언/VV',
#  '코드/NNG',
#  '트래블/NNG',
#  '스/VV',
#  '려/NNG',
#  '수집/NNG',
#  '채택/NNG',
#  '밖/NNG',
#  '겪/VV',
#  '취급/NNG',
#  '회원/NNG',
#  '담당/NNG',
#  '가입/NNG',
#  '점차/MAG',
#  '발/NNG',
#  '유한/VV',
#  '불과/MAG',
#  '각국/NNG',
#  '레이트/NNG',
#  '추정/NNG',
#  '문/VV',
#  '눈/NNG',
#  '곧/MAG',
#  '가격/NNG;상승/NNG',
#  '해커/NNG',
#  '적극적/VAX',
#  '넣/VV',
#  '돕/VV',
#  '활성화/NNG',
#  '부족/NNG',
#  '파악/NNG',
#  '물가/NNG',
#  '신용/NNG',
#  '퀀트/NNG',
#  '열풍/NNG',
#  '속/NNG',
#  '담/NNG',
#  '메시지/NNG',
#  '비판/NNG',
#  '남/VV',
#  '생성/NNG',
#  '소비/NNG',
#  '방향/NNG',
#  '조정/NNG',
#  '경고/NNG',
#  '생기/VV',
#  '소유/NNG',
#  '소송/NNG',
#  '거품/NNG',
#  '법원/NNG',
#  '살피/VV',
#  '못/MAG',
#  '홍/NNG',
#  '영역/NNG',
#  '지방/NNG',
#  '움직이/VV',
#  '사실/MAG',
#  '조작/NNG',
#  '단속/NNG',
#  '조달/NNG',
#  '힘/NNG',
#  '이동/NNG',
#  '유통/NNG',
#  '정하/VV',
#  '급락/NNG',
#  '자본/NNG',
#  '최종/NNG',
#  '관점/NNG',
#  '직원/NNG',
#  '탁방/NNG',
#  '번역/NNG',
#  '상품권/NNG',
#  '시범/NNG',
#  '애플리케이션/NNG',
#  '서로/MAG',
#  '얼마나/MAG',
#  '완전히/MAG',
#  '이끄/VV',
#  '자회사/NNG',
#  '사고/NNG',
#  '모두/NNG',
#  '실험/NNG',
#  '반/NNG',
#  '끝/NNG',
#  '만드/VV',
#  '심사/NNG',
#  '최고가/NNG',
#  '감독/NNG',
#  '권한/NNG',
#  '구하/VV',
#  '예고/NNG',
#  '합의/NNG',
#  '해지/NNG',
#  '사항/NNG',
#  '메인/VV',
#  '부채/NNG',
#  '의구심/NNG',
#  '피하/VV',
#  '집/NNG',
#  '매출/NNG',
#  '원인/NNG',
#  '급증/NNG',
#  '유량/NNG',
#  '감사/NNG',
#  '가격/NNG;하락/NNG',
#  '변동/NNG',
#  '비대/VV',
#  '협업/NNG',
#  '감시/NNG',
#  '방침/NNG',
#  '닷컴/NNG',
#  '형성/NNG',
#  '손/NNG',
#  '개최/NNG',
#  '차원/NNG',
#  '끌/VV',
#  '반영/NNG',
#  '추/NNG',
#  '금융위/NNG',
#  '선정/NNG',
#  '비중/NNG',
#  '디/NNG',
#  '별도/NNG',
#  '왜/MAG',
#  '비율/NNG',
#  '얼마/NNG',
#  '폐쇄/NNG',
#  '금융시스템/NNG',
#  '설립자/NNG',
#  '특성/NNG',
#  '캐시/NNG',
#  '대체/MAG',
#  '경신/NNG',
#  '투표/NNG',
#  '허용/NNG',
#  '측면/NNG',
#  '부과/NNG',
#  '프로/NNG',
#  '고민/NNG',
#  '반대/NNG',
#  '부자/NNG',
#  '준수/NNG',
#  '의하/VV',
#  '아트/NNG',
#  '해석/NNG',
#  '상장폐지/NNG',
#  '분명/MAG',
#  '책임/NNG',
#  '현물/NNG',
#  '알려진/VV',
#  '청산/NNG',
#  '변경/NNG',
#  '현황/NNG',
#  '벤처/NNG',
#  '작용/NNG',
#  '총괄/NNG',
#  '운영사/NNG',
#  '사상/NNG',
#  '파운드/NNG',
#  '위반/NNG',
#  '가깝/VA',
#  '고래/NNG',
#  '조건/NNG',
#  '찍/VV',
#  '긍정적/VAX',
#  '맞추/VV',
#  '배경/NNG',
#  '한/NNG',
#  '작성/NNG',
#  '은/NNG',
#  '협약/NNG',
#  '기술적/VAX',
#  '새로/MAG',
#  '흐름/NNG',
#  '종류/NNG',
#  '돌아/VV',
#  '키/NNG',
#  '움직임/NNG',
#  '삼/VV',
#  '그라운드/NNG',
#  '스타/NNG',
#  '입/VV',
#  '유튜브/NNG',
#  '그대로/MAG',
#  '나스닥/NNG',
#  '마스크/NNG',
#  '지침/NNG',
#  '대안/NNG',
#  '매입/NNG',
#  '간편/NNG',
#  '타/VV',
#  '강력/NNG',
#  '경기/NNG',
#  '맺/VV',
#  '실물/NNG',
#  '김치프리미엄/NNG',
#  '산하/NNG',
#  '바탕/NNG',
#  '백서/NNG',
#  '만나/VV',
#  '자산시장/NNG',
#  '실현/NNG',
#  '중개/NNG',
#  '완료/NNG',
#  '박사/NNG',
#  '파이/NNG',
#  '마지막/NNG',
#  '안정/NNG',
#  '어민/NNG',
#  '오비/NNG',
#  '부정적/VAX',
#  '정의/NNG',
#  '수리/NNG',
#  '블로그/NNG',
#  '건/NNG',
#  '부여/NNG',
#  '매매/NNG',
#  '분위기/NNG',
#  '위치/NNG',
#  '사전/NNG',
#  '진출/NNG',
#  '투기/NNG',
#  '버전/NNG',
#  '문화/NNG',
#  '수행/NNG',
#  '통/NNG',
#  '부담/NNG',
#  '풀/VV',
#  '본격/NNG',
#  '불구/NNG',
#  '외부/NNG',
#  '혜택/NNG',
#  '알려졌/VV',
#  '서명/NNG',
#  '증시/NNG',
#  '조성/NNG',
#  '만기/NNG',
#  '자/NNG',
#  '실패/NNG',
#  '테/NNG',
#  '입법/NNG',
#  '복잡/NNG',
#  '본인/NNG',
#  '취재/NNG',
#  '마케팅/NNG',
#  '수많/VA',
#  '특징/NNG',
#  '라이선스/NNG',
#  '너스/NNG',
#  '작가/NNG',
#  '진입/NNG',
#  '앤/NNG',
#  '반드시/MAG',
#  '거리/NNG',
#  '실적/NNG',
#  '장점/NNG',
#  '옵션/NNG',
#  '인기/NNG',
#  '국채/NNG',
#  '빔/NNG',
#  '스팀/NNG',
#  '박스/NNG',
#  '짧/VA',
#  '파이낸스/NNG',
#  '험/NNG',
#  '밋/NNG',
#  '풀이/NNG',
#  '유출/NNG',
#  '발행사/NNG',
#  '허가/NNG',
#  '인상/NNG',
#  '다크/NNG',
#  '자/VV',
#  '메이커/NNG',
#  '트랜잭션/NNG',
#  '종합/NNG',
#  '채굴장/NNG',
#  '최/NNG',
#  '실시간/NNG',
#  '전혀/MAG',
#  '약속/NNG',
#  '바라/VV',
#  '잠재/NNG',
#  '취득/NNG',
#  '나/VV',
#  '분류/NNG',
#  '해서/VV',
#  '수정/NNG',
#  '체이/NNG',
#  '전통/NNG',
#  '증여/NNG',
#  '길/NNG',
#  '레버리지/NNG',
#  '반감기/NNG',
#  '표현/NNG',
#  '드/VV',
#  '사라지/VV',
#  '계산/NNG',
#  '유입/NNG',
#  '신청서/NNG',
#  '동일/NNG',
#  '대기업/NNG',
#  '위협/NNG',
#  '지위/NNG',
#  '서류/NNG',
#  '과학/NNG',
#  '기여/NNG',
#  '끝/VV',
#  '유예/NNG',
#  '기구/NNG',
#  '이론/NNG',
#  '파이넥스/NNG',
#  '도구/NNG',
#  '역사/NNG',
#  '잘못/MAG',
#  '통상/NNG',
#  '재정/NNG',
#  '옮기/VV',
#  '사실상/MAG',
#  '정리/NNG',
#  '대중/NNG',
#  '들어가/VV',
#  '참석/NNG',
#  '예약/NNG',
#  '경매/NNG',
#  '출범/NNG',
#  '다수/NNG',
#  '바이러스/NNG',
#  '어렵/VV',
#  '빠지/VV',
#  '거래자/NNG',
#  '유자/NNG',
#  '완화/NNG',
#  '양도소득/NNG',
#  '력/NNG',
#  '멀/VA',
#  '적합/NNG',
#  '유일/NNG',
#  '걱정/NNG',
#  '실질/NNG',
#  '파일/NNG',
#  '파트/NNG',
#  '실행/NNG',
#  '업그레이드/NNG',
#  '노출/NNG',
#  '공식적/VAX',
#  '최저/NNG',
#  '꼽/VV',
#  '상승장/NNG',
#  '탁/NNG',
#  '가격/NNG;오르/VV',
#  '칼럼/NNG',
#  '지연/NNG',
#  '개설/NNG',
#  '나가/VV',
#  '몰리/VV',
#  '물량/NNG',
#  '재택근무/NNG',
#  '오래/MAG',
#  '듣/VV',
#  '모으/VV',
#  '팬/NNG',
#  '사이버/NNG',
#  '비밀/NNG',
#  '대가/NNG',
#  '테러/NNG',
#  '심리/NNG',
#  '꾸준히/MAG',
#  '넷/NNG',
#  '할인/NNG',
#  ...]

# %%
# article_word = test['token']
tmp = []

for i in tqdm(article_word):
    ar = [[],[]]
    ar[0].append(i)
    
    for j in i:
        
        if j[1:-1] in list(corp_dic.index):
            ar[1].append(word_score[[_[0] for _ in word_score].index(j[1:-1])][1])
    
    tmp.append(ar)
            
len(tmp)
# Out:
# 100%|██████████| 457/457 [00:34<00:00, 13.34it/s]
# 457

# %%
word_score[407]
# Out:
# ['실/VV', 1.1737156767009447]

# %%
word_score[[_[0] for _ in word_score].index('가상화폐/NNG')][1]
# Out:
# 0.5993441753366526

# %%
len(list(corp_dic.index))
# Out:
# 1358

# %%
tmp_df = pd.DataFrame(tmp)
tmp_df
# Out:
#                                                      0  \
# 0    [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '으로/MA...
# 1                      [['도/NNG', '자료/NNG', '으로/NNG']]
# 2    [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '도/NNG...
# 3                                [['도/NNG', '자료/NNG']]
# 4                      [['도/NNG', '자료/NNG', '으로/NNG']]
# ..                                                 ...
# 452  [['오름/NNG', '불구/NNG', '비트코인/NNG', '손실/NNG', '메...
# 453  [['블록체인/NNG', '개발/NNG', '하/VV', '위하/VV', '개방형/...
# 454  [['블록체인/NNG', '계열회사/NNG', '트리/NNG', '대체/MAG', ...
# 455  [['프로/NNG', '농구/NNG', '구단/NNG', '이자/NNG', '억만장...
# 456  [['인스타그램/NNG', '비슷/NNG', '수법/NNG', '암호화폐/NNG',...
#
#                                                      1
# 0    [0.8184082647397646, 0.7713484752104514, 0.818...
# 1    [0.8184082647397646, 0.7713484752104514, 0.719...
# 2    [0.8184082647397646, 0.7713484752104514, 0.818...
# 3             [0.8184082647397646, 0.7713484752104514]
# 4    [0.8184082647397646, 0.7713484752104514, 0.719...
# ..                                                 ...
# 452  [0.799125567115537, 1.2043963904384163, 0.8172...
# 453  [0.8227930490684361, 0.805874938459418, 0.9723...
# 454  [0.8227930490684361, 0.9829244475521104, 0.542...
# 455  [0.998906958894421, 0.654668253060036, 0.73765...
# 456  [1.4863735548348986, 1.6781636909426274, 1.142...
#
# [457 rows x 2 columns]

# %% [markdown]
# ---

# %%
test
# Out:
#     created_date                                            article  \
# 0     2018-04-19                    도자료는     도자료는 으로           도자료는
# 1     2018-04-20                                      도자료는 으로
# 2     2018-04-24                    도자료는     도자료는     도자료는 으로
# 3     2018-04-25                                               도자료는
# 4     2018-04-26                                      도자료는 으로
# ..           ...                                                ...
# 452   2021-03-03   지난 일 오름 에도 불구하고 비트코인은  말 동안 손실분을 메우기 위해 고군분투하...
# 453   2021-03-04   블록체인 기반 웹 브라우저 브레이브가 자체 검색엔진을 개발한다 이를 위해 브레이브...
# 454   2021-03-08   게임회사 위메이드의 블록체인 계열회사 위메이드트리가 대체불가능토큰 시장에 진출한다...
# 455   2021-03-09   미국프로농구 댈러스 매버릭스 구단 이자 억만장자 기업가인 마크 큐반이 지난 일 도...
# 456   2021-03-10   인스타그램에서 비슷한 수법의 암호화폐 사기로 매달 수만달러의 자금이 도난당하고 있...
#
#              price   label                                              token
# 0    8754047.24105 1.00000  [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '으로/MA...
# 1    9020520.71192 1.00000                    [['도/NNG', '자료/NNG', '으로/NNG']]
# 2    9980132.11203 1.00000  [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '도/NNG...
# 3   10290519.14234 1.00000                              [['도/NNG', '자료/NNG']]
# 4    9799738.52757 0.00000                    [['도/NNG', '자료/NNG', '으로/NNG']]
# ..             ...     ...                                                ...
# 452 56740992.17798 1.00000  [['오름/NNG', '불구/NNG', '비트코인/NNG', '손실/NNG', '메...
# 453 57341344.23252 1.00000  [['블록체인/NNG', '개발/NNG', '하/VV', '위하/VV', '개방형/...
# 454 57765992.83854 1.00000  [['블록체인/NNG', '계열회사/NNG', '트리/NNG', '대체/MAG', ...
# 455 60430299.86229 1.00000  [['프로/NNG', '농구/NNG', '구단/NNG', '이자/NNG', '억만장...
# 456 62622616.62071 1.00000  [['인스타그램/NNG', '비슷/NNG', '수법/NNG', '암호화폐/NNG',...
#
# [457 rows x 5 columns]

# %%
tmp_df = pd.DataFrame(tmp)
# tmp_df

f_df = pd.concat([test,tmp_df],axis=1)
f_df.pop(0)
f_df.columns = ['created_date','article','price','label','token','score']
f_df
# Out:
#     created_date                                            article  \
# 0     2018-04-19                    도자료는     도자료는 으로           도자료는
# 1     2018-04-20                                      도자료는 으로
# 2     2018-04-24                    도자료는     도자료는     도자료는 으로
# 3     2018-04-25                                               도자료는
# 4     2018-04-26                                      도자료는 으로
# ..           ...                                                ...
# 452   2021-03-03   지난 일 오름 에도 불구하고 비트코인은  말 동안 손실분을 메우기 위해 고군분투하...
# 453   2021-03-04   블록체인 기반 웹 브라우저 브레이브가 자체 검색엔진을 개발한다 이를 위해 브레이브...
# 454   2021-03-08   게임회사 위메이드의 블록체인 계열회사 위메이드트리가 대체불가능토큰 시장에 진출한다...
# 455   2021-03-09   미국프로농구 댈러스 매버릭스 구단 이자 억만장자 기업가인 마크 큐반이 지난 일 도...
# 456   2021-03-10   인스타그램에서 비슷한 수법의 암호화폐 사기로 매달 수만달러의 자금이 도난당하고 있...
#
#              price   label                                              token  \
# 0    8754047.24105 1.00000  [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '으로/MA...
# 1    9020520.71192 1.00000                    [['도/NNG', '자료/NNG', '으로/NNG']]
# 2    9980132.11203 1.00000  [['도/NNG', '자료/NNG', '도/NNG', '자료/NNG', '도/NNG...
# 3   10290519.14234 1.00000                              [['도/NNG', '자료/NNG']]
# 4    9799738.52757 0.00000                    [['도/NNG', '자료/NNG', '으로/NNG']]
# ..             ...     ...                                                ...
# 452 56740992.17798 1.00000  [['오름/NNG', '불구/NNG', '비트코인/NNG', '손실/NNG', '메...
# 453 57341344.23252 1.00000  [['블록체인/NNG', '개발/NNG', '하/VV', '위하/VV', '개방형/...
# 454 57765992.83854 1.00000  [['블록체인/NNG', '계열회사/NNG', '트리/NNG', '대체/MAG', ...
# 455 60430299.86229 1.00000  [['프로/NNG', '농구/NNG', '구단/NNG', '이자/NNG', '억만장...
# 456 62622616.62071 1.00000  [['인스타그램/NNG', '비슷/NNG', '수법/NNG', '암호화폐/NNG',...
#
#                                                  score
# 0    [0.8184082647397646, 0.7713484752104514, 0.818...
# 1    [0.8184082647397646, 0.7713484752104514, 0.719...
# 2    [0.8184082647397646, 0.7713484752104514, 0.818...
# 3             [0.8184082647397646, 0.7713484752104514]
# 4    [0.8184082647397646, 0.7713484752104514, 0.719...
# ..                                                 ...
# 452  [0.799125567115537, 1.2043963904384163, 0.8172...
# 453  [0.8227930490684361, 0.805874938459418, 0.9723...
# 454  [0.8227930490684361, 0.9829244475521104, 0.542...
# 455  [0.998906958894421, 0.654668253060036, 0.73765...
# 456  [1.4863735548348986, 1.6781636909426274, 1.142...
#
# [457 rows x 6 columns]

# %%
sum(f_df['score'][4])/len(f_df['score'][4])
# Out:
# 0.7696565834513996

# %%
tone_score = []

print("기사 갯수",len(f_df['score']))
print("기사에 있는 단어 갯수",len(f_df['score'][0]))

for i in tqdm(range(len(f_df['score']))):
    if len(f_df['score'][i]) != 0:
        tone_avg = sum(f_df['score'][i])/len(f_df['score'][i])
        tone_score.append(tone_avg)
    else:
        tone_avg = None
        tone_score.append(tone_avg)
        
len(tone_score)
# Out:
# 100%|██████████| 457/457 [00:00<00:00, 37191.19it/s]
# 기사 갯수 457
# 기사에 있는 단어 갯수 7
# 457

# %%
pd.DataFrame(tone_score)
# Out:
#           0
# 0   0.76923
# 1   0.76966
# 2   0.78407
# 3   0.79488
# 4   0.76966
# ..      ...
# 452 1.09189
# 453 1.31675
# 454     inf
# 455     inf
# 456 1.17200
#
# [457 rows x 1 columns]

# %%
analysis_df = pd.concat([f_df,pd.DataFrame(tone_score)],axis=1).dropna()
analysis_df.columns = ['created_date','article','price','label','token','score','article_score']
analysis_df = analysis_df[['created_date','article','article_score']]
analysis_df
# Out:
#     created_date                                            article  \
# 0     2018-04-19                    도자료는     도자료는 으로           도자료는
# 1     2018-04-20                                      도자료는 으로
# 2     2018-04-24                    도자료는     도자료는     도자료는 으로
# 3     2018-04-25                                               도자료는
# 4     2018-04-26                                      도자료는 으로
# ..           ...                                                ...
# 452   2021-03-03   지난 일 오름 에도 불구하고 비트코인은  말 동안 손실분을 메우기 위해 고군분투하...
# 453   2021-03-04   블록체인 기반 웹 브라우저 브레이브가 자체 검색엔진을 개발한다 이를 위해 브레이브...
# 454   2021-03-08   게임회사 위메이드의 블록체인 계열회사 위메이드트리가 대체불가능토큰 시장에 진출한다...
# 455   2021-03-09   미국프로농구 댈러스 매버릭스 구단 이자 억만장자 기업가인 마크 큐반이 지난 일 도...
# 456   2021-03-10   인스타그램에서 비슷한 수법의 암호화폐 사기로 매달 수만달러의 자금이 도난당하고 있...
#
#      article_score
# 0          0.76923
# 1          0.76966
# 2          0.78407
# 3          0.79488
# 4          0.76966
# ..             ...
# 452        1.09189
# 453        1.31675
# 454            inf
# 455            inf
# 456        1.17200
#
# [456 rows x 3 columns]

# %%
price = pd.read_csv('/Users/yoo/Data-dev/nlp/dev/price.csv')
price.columns = ['created_date','price','before_price','label']
price = price[['created_date','price','label']]
price = price.dropna()
price
# Out:
#      created_date          price   label
# 1      2018-03-16  9024833.95469 1.00000
# 2      2018-03-17  9056906.80354 1.00000
# 3      2018-03-18  8470860.29412 0.00000
# 4      2018-03-19  8970286.25831 1.00000
# 5      2018-03-20  9464396.02542 1.00000
# ...           ...            ...     ...
# 1318   2021-10-23 74501866.23316 0.00000
# 1319   2021-10-24 74478050.59524 0.00000
# 1320   2021-10-25 75178560.00732 1.00000
# 1321   2021-10-26 75581706.19076 1.00000
# 1322   2021-10-27 72994468.79360 0.00000
#
# [1322 rows x 3 columns]

# %%
analysis_df = pd.merge(analysis_df, price, how='left', on='created_date')
analysis_df
# Out:
#     created_date                                            article  \
# 0     2018-04-19                    도자료는     도자료는 으로           도자료는
# 1     2018-04-20                                      도자료는 으로
# 2     2018-04-24                    도자료는     도자료는     도자료는 으로
# 3     2018-04-25                                               도자료는
# 4     2018-04-26                                      도자료는 으로
# ..           ...                                                ...
# 451   2021-03-03   지난 일 오름 에도 불구하고 비트코인은  말 동안 손실분을 메우기 위해 고군분투하...
# 452   2021-03-04   블록체인 기반 웹 브라우저 브레이브가 자체 검색엔진을 개발한다 이를 위해 브레이브...
# 453   2021-03-08   게임회사 위메이드의 블록체인 계열회사 위메이드트리가 대체불가능토큰 시장에 진출한다...
# 454   2021-03-09   미국프로농구 댈러스 매버릭스 구단 이자 억만장자 기업가인 마크 큐반이 지난 일 도...
# 455   2021-03-10   인스타그램에서 비슷한 수법의 암호화폐 사기로 매달 수만달러의 자금이 도난당하고 있...
#
#      article_score          price   label
# 0          0.76923  8754047.24105 1.00000
# 1          0.76966  9020520.71192 1.00000
# 2          0.78407  9980132.11203 1.00000
# 3          0.79488 10290519.14234 1.00000
# 4          0.76966  9799738.52757 0.00000
# ..             ...            ...     ...
# 451        1.09189 56740992.17798 1.00000
# 452        1.31675 57341344.23252 1.00000
# 453            inf 57765992.83854 1.00000
# 454            inf 60430299.86229 1.00000
# 455        1.17200 62622616.62071 1.00000
#
# [456 rows x 5 columns]

# %%
analysis_df = analysis_df.dropna()
analysis_df['article_score'] = [str(_).replace('inf','0.8309676763645697') for _ in analysis_df['article_score']]
analysis_df['article_score'].astype(float)
analysis_df
# Out:
#     created_date                                            article  \
# 0     2018-04-19                    도자료는     도자료는 으로           도자료는
# 1     2018-04-20                                      도자료는 으로
# 2     2018-04-24                    도자료는     도자료는     도자료는 으로
# 3     2018-04-25                                               도자료는
# 4     2018-04-26                                      도자료는 으로
# ..           ...                                                ...
# 451   2021-03-03   지난 일 오름 에도 불구하고 비트코인은  말 동안 손실분을 메우기 위해 고군분투하...
# 452   2021-03-04   블록체인 기반 웹 브라우저 브레이브가 자체 검색엔진을 개발한다 이를 위해 브레이브...
# 453   2021-03-08   게임회사 위메이드의 블록체인 계열회사 위메이드트리가 대체불가능토큰 시장에 진출한다...
# 454   2021-03-09   미국프로농구 댈러스 매버릭스 구단 이자 억만장자 기업가인 마크 큐반이 지난 일 도...
# 455   2021-03-10   인스타그램에서 비슷한 수법의 암호화폐 사기로 매달 수만달러의 자금이 도난당하고 있...
#
#           article_score          price   label
# 0    0.7692342343595938  8754047.24105 1.00000
# 1    0.7696565834513996  9020520.71192 1.00000
# 2    0.7840690328935187  9980132.11203 1.00000
# 3     0.794878369975108 10290519.14234 1.00000
# 4    0.7696565834513996  9799738.52757 0.00000
# ..                  ...            ...     ...
# 451  1.0918875718800378 56740992.17798 1.00000
# 452   1.316746157226535 57341344.23252 1.00000
# 453  0.8309676763645697 57765992.83854 1.00000
# 454  0.8309676763645697 60430299.86229 1.00000
# 455  1.1720013529740287 62622616.62071 1.00000
#
# [456 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %% [markdown]
# ### Parameters 변경

# %%
article_scaled = pd.DataFrame(scaler.fit_transform(analysis_df[['article_score']].rolling(window=120).mean()))
price_scaled = pd.DataFrame(scaler.fit_transform(analysis_df[['price']].rolling(window=120).mean()))

s = pd.concat([article_scaled, price_scaled],axis=1)
s.columns = ['tone','price']
s
# Out:
#        tone   price
# 0       nan     nan
# 1       nan     nan
# 2       nan     nan
# 3       nan     nan
# 4       nan     nan
# ..      ...     ...
# 451 1.53828 3.46054
# 452 1.53298 3.56276
# 453 1.52905 3.66601
# 454 1.52905 3.77528
# 455 1.52311 3.88897
#
# [456 rows x 2 columns]

# %%
plt.figure(figsize=(7,4))
plt.plot(s)
plt.title("Moving average 120 days: {}".format(article_scaled[0].corr(price_scaled[0])), fontsize=15)
plt.xlabel("Timestamp", fontsize=15)
plt.ylabel("Trend", fontsize=15)
plt.legend(s.columns,fontsize=15)
print("* corr score: ",article_scaled[0].corr(price_scaled[0]))
# Out:
# * corr score:  0.7868459101571907

# %%
analysis_df.sort_values(by='article_score',ascending=False)
# Out:
#     created_date                                            article  \
# 395   2020-09-30   유럽 암호화폐 거래소 비트판다 가 시리즈 투자로 만달러 약 억원의 투자금을 유치했...
# 2     2018-03-19   콘텐츠 생산자와 추천인에게  상 는 이용자 정 로 부 독점 페이스북 등에 반기 작...
# 307   2020-03-03   블록체인 기반 맛집 플랫폼 소다플레이 개발사 몬스터큐브가 암호화폐 지갑 서비스 비...
# 464   2021-03-09   페이팔이 암호화폐 수탁업체 커브 인수를 확정했다 페이팔은 일 현지시간 올해 분기 ...
# 553   2021-08-10    계 최대 규모 스테이블코인 테더 의 발행사 테더 가 예치금 구성에 대한  고서를...
# ..           ...                                                ...
# 233   2019-09-10   이처럼 페이스북은 리브라를 출시하기에 앞서 규  당국을 설득하기 위해 분 히 움직...
# 247   2019-10-16       도자료는 으로           도자료는 으로           도자료는 ...
# 347   2020-06-03    암호화폐 정 공시 플랫폼 쟁글 의 예약공시  도에 대한 원성이 들끓고 있다 일부...
# 419   2020-12-02   오는 일부터 공인인증서가 폐지된다 대신 액티브엑스 등의 프로그램을 설치하지 않아도...
# 132   2019-02-14       도자료는 으로           도자료는  변 친구들에게 컨센서스 행사를 ...
#
#           article_score          price   label
# 395  2.3987455963078186 12513400.50469 1.00000
# 2    2.1405847963411846  8970286.25831 1.00000
# 307  1.5411884098327666 10586310.61279 1.00000
# 464  1.4977382807324084 60430299.86229 1.00000
# 553  1.4441789567214256 52648607.22477 1.00000
# ..                  ...            ...     ...
# 233  0.9047440752619322 12234394.47368 0.00000
# 247   0.897048508018637  9656952.17782 0.00000
# 347  0.8963518587556923 11481780.46218 0.00000
# 419  0.8712408418113071 20857794.01408 0.00000
# 132  0.8688739212565101  3984371.36673 0.00000
#
# [606 rows x 5 columns]

# %%
# Out:
# <ipython-input-49-ad2f90731b03>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analysis_df['article_score'] = [str(_).replace('inf','0.9309676763645697') for _ in analysis_df['article_score']]
#     created_date                                            article  \
# 1     2018-03-16   라인의 금융 자회사 라인 파이낸셜 통해 일본 금융청에 가상화폐 거래 사업자 신청 ...
# 2     2018-03-19   콘텐츠 생산자와 추천인에게  상 는 이용자 정 로 부 독점 페이스북 등에 반기 작...
# 3     2018-03-29       도자료는 당신이 풀 노드로 돌리고 있는 블록체인에 아동 포르노가 연결되어 ...
# 4     2018-04-03                                      도자료는 으로
# 5     2018-04-04           도자료는 으로           도자료는 으로           도자료는
# ..           ...                                                ...
# 602   2021-10-21    신고점 경신한 비트코인  말엔 리스크 관리 우선해야 비트코인은 지난 일 밤 시경...
# 603   2021-10-22   일 금융위원회 위원장 고승범 는 지난 월 일 가상자산 사업자 신고 마감 이후 먹튀...
# 604   2021-10-25   조정의 끝을 알고 싶다면 만 달러 지지해야 비트코인은 일 오후 시경 만 달러 선까...
# 605   2021-10-26   미국 증권 금융의 최고 규  기구인 증권거래위원회 가 억 달러 규모의 스테이블 코...
# 606   2021-10-27    가상자산 데이터 분석 업체 글래스노드가 일 스위스 시간  간 온체인  고서 를 ...
#
#           article_score         price  label
# 1    1.2939471518268237  9.024834e+06    1.0
# 2    2.1405847963411846  8.970286e+06    1.0
# 3    0.9797488220940854  8.437139e+06    0.0
# 4    0.9491393674529895  7.904069e+06    1.0
# 5     0.918019318949795  7.943745e+06    1.0
# ..                  ...           ...    ...
# 602  1.0661978781685453  7.887421e+07    1.0
# 603    1.00698531993298  7.663260e+07    0.0
# 604  1.0778009622336067  7.517856e+07    1.0
# 605  1.1314813887929356  7.558171e+07    1.0
# 606    1.01720855204335  7.299447e+07    0.0
#
# [606 rows x 5 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Test data comparison

# %%
# %%time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from tqdm import tqdm

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
# Out:
# CPU times: user 1.26 s, sys: 418 ms, total: 1.68 s
# Wall time: 1.79 s

# %%
pd.options.display.float_format = '{:5f}'.format

# %%
price = pd.read_csv('/Users/yoo/Data-dev/nlp/dev/price.csv')
price.columns = ['created_date','price','before_price','label']
price
# Out:
#      created_date           price    before_price    label
# 0      2018-03-15  9010234.208908             nan      nan
# 1      2018-03-16  9024833.954689  9010234.208908 1.000000
# 2      2018-03-17  9056906.803543  9024833.954689 1.000000
# 3      2018-03-18  8470860.294118  9056906.803543 0.000000
# 4      2018-03-19  8970286.258314  8470860.294118 1.000000
# ...           ...             ...             ...      ...
# 1318   2021-10-23 74501866.233163 76632600.673195 0.000000
# 1319   2021-10-24 74478050.595238 74501866.233163 0.000000
# 1320   2021-10-25 75178560.007318 74478050.595238 1.000000
# 1321   2021-10-26 75581706.190764 75178560.007318 1.000000
# 1322   2021-10-27 72994468.793601 75581706.190764 0.000000
#
# [1323 rows x 4 columns]

# %%
corp_dic_comp = pd.read_csv('/Users/yoo/Data-dev/nlp/dev/corp_dic_comp.csv')
corp_dic_comp
# Out:
#           Unnamed: 0  total  up  down
# 0      비용/NNG;부담/NNG      1   0     1
# 1       유동성/NNG;높/VV      1   0     1
# 2        가격/NNG;낮/VA      1   0     1
# 3            법무부/NNG     35  12    23
# 4             소속/NNG     23  13    10
# ...              ...    ...  ..   ...
# 11517         몬드/NNG      1   1     0
# 11518         퍼트/NNG      1   1     0
# 11519   좋/VA;고평가/NNG      1   0     1
# 11520       차익실현/NNG      1   0     1
# 11521         약진/NNG      1   0     1
#
# [11522 rows x 4 columns]

# %%
test = pd.read_csv('/Users/yoo/Data-dev/nlp/dev/article_token.csv')
test.columns = ['created_date','article','token']
test = test[['created_date', 'article', 'token']]
test
# Out:
#     created_date                                            article  \
# 0     2018-03-15   김동연 부총리 겸 기획재정부 장관은 가상통화에  금을 매기는 게 바람직한지 논의 ...
# 1     2018-03-16   라인의 금융 자회사 라인 파이낸셜 통해 일본 금융청에 가상화폐 거래 사업자 신청 ...
# 2     2018-03-19   콘텐츠 생산자와 추천인에게  상 는 이용자 정 로 부 독점 페이스북 등에 반기 작...
# 3     2018-03-29       도자료는 당신이 풀 노드로 돌리고 있는 블록체인에 아동 포르노가 연결되어 ...
# 4     2018-04-03                                      도자료는 으로
# ..           ...                                                ...
# 605   2021-10-21    신고점 경신한 비트코인  말엔 리스크 관리 우선해야 비트코인은 지난 일 밤 시경...
# 606   2021-10-22   일 금융위원회 위원장 고승범 는 지난 월 일 가상자산 사업자 신고 마감 이후 먹튀...
# 607   2021-10-25   조정의 끝을 알고 싶다면 만 달러 지지해야 비트코인은 일 오후 시경 만 달러 선까...
# 608   2021-10-26   미국 증권 금융의 최고 규  기구인 증권거래위원회 가 억 달러 규모의 스테이블 코...
# 609   2021-10-27    가상자산 데이터 분석 업체 글래스노드가 일 스위스 시간  간 온체인  고서 를 ...
#
#                                                  token
# 0    [['가상화폐/NNG', '금/NNG', '매기/VV', '바람직/NNG', '논의...
# 1    [['라인/NNG', '금융/NNG', '자회사/NNG', '라인/NNG', '파이...
# 2    [['생산자/NNG', '추천인/NNG', '상/NNG', '부/NNG', '독점/...
# 3    [['도/NNG', '자료/NNG', '풀/VV', '노드/NNG', '돌리/VV'...
# 4                      [['도/NNG', '자료/NNG', '으로/NNG']]
# ..                                                 ...
# 605  [['신고점/NNG', '경신/NNG', '하/VV', '비트코인/NNG', '엔/...
# 606  [['가상/NNG', '자산/NNG', '사업자/NNG', '신고/NNG', '마감...
# 607  [['조정/NNG', '끝/NNG', '알/VV', '달러/NNG', '지지/NNG...
# 608  [['증권금융/NNG', '최고/NNG', '규/NNG', '기구/NNG', '증권...
# 609  [['가상/NNG', '자산/NNG', '데이터/NNG', '분석/NNG', '업체...
#
# [610 rows x 3 columns]

# %%
article_word = []

for i in test['token']:
    q = i.replace('"','').replace('[[','').replace(']]','').split(', ')
    article_word.append(q)

article_word[0][0]
# Out:
# "'가상화폐/NNG'"

# %%
# %%time
word_score = []

for pair in zip(crypto_list, crypto_score):
    pair = list(pair)
    word_score.append(pair)
    
word_score[:5]
# Out:
# CPU times: user 6.24 ms, sys: 162 µs, total: 6.4 ms
# Wall time: 6.37 ms
# [['하/VV', 1.0457968598871377],
#  ['되/VV', 1.0402673601273984],
#  ['암호화폐/NNG', 1.1898582364501997],
#  ['비트코인/NNG', 1.1805244062781202],
#  ['있/VV', 0.9116135563947094]]

# %%
# article_word = test['token']
tmp = []

try:
    for i in tqdm(article_word):
        ar = [[],[]]
        ar[0].append(i)

        for j in i:

            if j[1:-1] in list(corp_dic.index):
                ar[1].append(word_score[[_[0] for _ in word_score].index(j[1:-1])][1])
#             else:
#                 ar[1].append(0)

        tmp.append(ar)
        
except ValueError as e:
    print(e)
            
len(tmp)
# Out:
# 100%|██████████| 610/610 [01:19<00:00,  7.70it/s]
# 610

# %%
pd.DataFrame(tmp)
# Out:
#                                                      0  \
# 0    [['가상화폐/NNG', '금/NNG', '매기/VV', '바람직/NNG', '논의...
# 1    [['라인/NNG', '금융/NNG', '자회사/NNG', '라인/NNG', '파이...
# 2    [['생산자/NNG', '추천인/NNG', '상/NNG', '부/NNG', '독점/...
# 3    [['도/NNG', '자료/NNG', '풀/VV', '노드/NNG', '돌리/VV'...
# 4                      [['도/NNG', '자료/NNG', '으로/NNG']]
# ..                                                 ...
# 605  [['신고점/NNG', '경신/NNG', '하/VV', '비트코인/NNG', '엔/...
# 606  [['가상/NNG', '자산/NNG', '사업자/NNG', '신고/NNG', '마감...
# 607  [['조정/NNG', '끝/NNG', '알/VV', '달러/NNG', '지지/NNG...
# 608  [['증권금융/NNG', '최고/NNG', '규/NNG', '기구/NNG', '증권...
# 609  [['가상/NNG', '자산/NNG', '데이터/NNG', '분석/NNG', '업체...
#
#                                                      1
# 0    [1.2584056906705834, 2.5478605783533586, 0.518...
# 1    [0.13735197247443998, 1.0125835263999128, 0.53...
# 2    [1.0587547878238082, 1.110357962356397, 1.8668...
# 3    [1.0399506487350458, 0.9923616304426492, 1.037...
# 4    [1.0399506487350458, 0.9923616304426492, 1.633...
# ..                                                 ...
# 605  [0.2722512311546935, 0.9153954438824478, 1.045...
# 606  [0.8675510929877028, 0.8942393379816671, 0.741...
# 607  [0.9469608040163253, 1.3612561557734675, 1.113...
# 608  [0.7448605112111094, 1.0727068917333231, 1.122...
# 609  [0.8675510929877028, 0.8942393379816671, 0.648...
#
# [610 rows x 2 columns]

# %%
semi_test = pd.merge(test,price, how='left',on='created_date')
semi_test = semi_test[['created_date','article','token','price','label']]
semi_test
# Out:
#     created_date                                            article  \
# 0     2018-03-15   김동연 부총리 겸 기획재정부 장관은 가상통화에  금을 매기는 게 바람직한지 논의 ...
# 1     2018-03-16   라인의 금융 자회사 라인 파이낸셜 통해 일본 금융청에 가상화폐 거래 사업자 신청 ...
# 2     2018-03-19   콘텐츠 생산자와 추천인에게  상 는 이용자 정 로 부 독점 페이스북 등에 반기 작...
# 3     2018-03-29       도자료는 당신이 풀 노드로 돌리고 있는 블록체인에 아동 포르노가 연결되어 ...
# 4     2018-04-03                                      도자료는 으로
# ..           ...                                                ...
# 605   2021-10-21    신고점 경신한 비트코인  말엔 리스크 관리 우선해야 비트코인은 지난 일 밤 시경...
# 606   2021-10-22   일 금융위원회 위원장 고승범 는 지난 월 일 가상자산 사업자 신고 마감 이후 먹튀...
# 607   2021-10-25   조정의 끝을 알고 싶다면 만 달러 지지해야 비트코인은 일 오후 시경 만 달러 선까...
# 608   2021-10-26   미국 증권 금융의 최고 규  기구인 증권거래위원회 가 억 달러 규모의 스테이블 코...
# 609   2021-10-27    가상자산 데이터 분석 업체 글래스노드가 일 스위스 시간  간 온체인  고서 를 ...
#
#                                                  token           price  \
# 0    [['가상화폐/NNG', '금/NNG', '매기/VV', '바람직/NNG', '논의...  9010234.208908
# 1    [['라인/NNG', '금융/NNG', '자회사/NNG', '라인/NNG', '파이...  9024833.954689
# 2    [['생산자/NNG', '추천인/NNG', '상/NNG', '부/NNG', '독점/...  8970286.258314
# 3    [['도/NNG', '자료/NNG', '풀/VV', '노드/NNG', '돌리/VV'...  8437138.682345
# 4                      [['도/NNG', '자료/NNG', '으로/NNG']]  7904068.976898
# ..                                                 ...             ...
# 605  [['신고점/NNG', '경신/NNG', '하/VV', '비트코인/NNG', '엔/... 78874213.677081
# 606  [['가상/NNG', '자산/NNG', '사업자/NNG', '신고/NNG', '마감... 76632600.673195
# 607  [['조정/NNG', '끝/NNG', '알/VV', '달러/NNG', '지지/NNG... 75178560.007318
# 608  [['증권금융/NNG', '최고/NNG', '규/NNG', '기구/NNG', '증권... 75581706.190764
# 609  [['가상/NNG', '자산/NNG', '데이터/NNG', '분석/NNG', '업체... 72994468.793601
#
#        label
# 0        nan
# 1   1.000000
# 2   1.000000
# 3   0.000000
# 4   1.000000
# ..       ...
# 605 1.000000
# 606 0.000000
# 607 1.000000
# 608 1.000000
# 609 0.000000
#
# [610 rows x 5 columns]

# %%
tmp_df = pd.DataFrame(tmp)
# tmp_df

f_df = pd.concat([semi_test,tmp_df],axis=1)
f_df.pop(0)
f_df.columns = ['created_date','article','token','price','label','score']
f_df
# Out:
#     created_date                                            article  \
# 0     2018-03-15   김동연 부총리 겸 기획재정부 장관은 가상통화에  금을 매기는 게 바람직한지 논의 ...
# 1     2018-03-16   라인의 금융 자회사 라인 파이낸셜 통해 일본 금융청에 가상화폐 거래 사업자 신청 ...
# 2     2018-03-19   콘텐츠 생산자와 추천인에게  상 는 이용자 정 로 부 독점 페이스북 등에 반기 작...
# 3     2018-03-29       도자료는 당신이 풀 노드로 돌리고 있는 블록체인에 아동 포르노가 연결되어 ...
# 4     2018-04-03                                      도자료는 으로
# ..           ...                                                ...
# 605   2021-10-21    신고점 경신한 비트코인  말엔 리스크 관리 우선해야 비트코인은 지난 일 밤 시경...
# 606   2021-10-22   일 금융위원회 위원장 고승범 는 지난 월 일 가상자산 사업자 신고 마감 이후 먹튀...
# 607   2021-10-25   조정의 끝을 알고 싶다면 만 달러 지지해야 비트코인은 일 오후 시경 만 달러 선까...
# 608   2021-10-26   미국 증권 금융의 최고 규  기구인 증권거래위원회 가 억 달러 규모의 스테이블 코...
# 609   2021-10-27    가상자산 데이터 분석 업체 글래스노드가 일 스위스 시간  간 온체인  고서 를 ...
#
#                                                  token           price  \
# 0    [['가상화폐/NNG', '금/NNG', '매기/VV', '바람직/NNG', '논의...  9010234.208908
# 1    [['라인/NNG', '금융/NNG', '자회사/NNG', '라인/NNG', '파이...  9024833.954689
# 2    [['생산자/NNG', '추천인/NNG', '상/NNG', '부/NNG', '독점/...  8970286.258314
# 3    [['도/NNG', '자료/NNG', '풀/VV', '노드/NNG', '돌리/VV'...  8437138.682345
# 4                      [['도/NNG', '자료/NNG', '으로/NNG']]  7904068.976898
# ..                                                 ...             ...
# 605  [['신고점/NNG', '경신/NNG', '하/VV', '비트코인/NNG', '엔/... 78874213.677081
# 606  [['가상/NNG', '자산/NNG', '사업자/NNG', '신고/NNG', '마감... 76632600.673195
# 607  [['조정/NNG', '끝/NNG', '알/VV', '달러/NNG', '지지/NNG... 75178560.007318
# 608  [['증권금융/NNG', '최고/NNG', '규/NNG', '기구/NNG', '증권... 75581706.190764
# 609  [['가상/NNG', '자산/NNG', '데이터/NNG', '분석/NNG', '업체... 72994468.793601
#
#        label                                              score
# 0        nan  [1.2584056906705834, 2.5478605783533586, 0.518...
# 1   1.000000  [0.13735197247443998, 1.0125835263999128, 0.53...
# 2   1.000000  [1.0587547878238082, 1.110357962356397, 1.8668...
# 3   0.000000  [1.0399506487350458, 0.9923616304426492, 1.037...
# 4   1.000000  [1.0399506487350458, 0.9923616304426492, 1.633...
# ..       ...                                                ...
# 605 1.000000  [0.2722512311546935, 0.9153954438824478, 1.045...
# 606 0.000000  [0.8675510929877028, 0.8942393379816671, 0.741...
# 607 1.000000  [0.9469608040163253, 1.3612561557734675, 1.113...
# 608 1.000000  [0.7448605112111094, 1.0727068917333231, 1.122...
# 609 0.000000  [0.8675510929877028, 0.8942393379816671, 0.648...
#
# [610 rows x 6 columns]

# %%
# %%time
tone_score = []

print("기사 갯수",len(f_df['score']))
print("기사에 있는 단어 갯수",len(f_df['score'][0]))

for i in tqdm(range(len(f_df['score']))):
    if len(f_df['score'][i]) != 0:
        tone_avg = sum(f_df['score'][i])/len(f_df['score'][i])
        tone_score.append(tone_avg)
    else:
        tone_avg = None
        tone_score.append(tone_avg)
        
len(tone_score)
# Out:
# 100%|██████████| 610/610 [00:00<00:00, 34762.10it/s]
# 기사 갯수 610
# 기사에 있는 단어 갯수 1408
# 610

# %%
analysis_df = pd.concat([f_df,pd.DataFrame(tone_score)],axis=1).dropna()
analysis_df.columns = ['created_date','article','token','price','label','score','article_score']
analysis_df = analysis_df[['created_date','article','article_score']]
analysis_df
# Out:
#     created_date                                            article  \
# 1     2018-03-16   라인의 금융 자회사 라인 파이낸셜 통해 일본 금융청에 가상화폐 거래 사업자 신청 ...
# 2     2018-03-19   콘텐츠 생산자와 추천인에게  상 는 이용자 정 로 부 독점 페이스북 등에 반기 작...
# 3     2018-03-29       도자료는 당신이 풀 노드로 돌리고 있는 블록체인에 아동 포르노가 연결되어 ...
# 4     2018-04-03                                      도자료는 으로
# 5     2018-04-04           도자료는 으로           도자료는 으로           도자료는
# ..           ...                                                ...
# 605   2021-10-21    신고점 경신한 비트코인  말엔 리스크 관리 우선해야 비트코인은 지난 일 밤 시경...
# 606   2021-10-22   일 금융위원회 위원장 고승범 는 지난 월 일 가상자산 사업자 신고 마감 이후 먹튀...
# 607   2021-10-25   조정의 끝을 알고 싶다면 만 달러 지지해야 비트코인은 일 오후 시경 만 달러 선까...
# 608   2021-10-26   미국 증권 금융의 최고 규  기구인 증권거래위원회 가 억 달러 규모의 스테이블 코...
# 609   2021-10-27    가상자산 데이터 분석 업체 글래스노드가 일 스위스 시간  간 온체인  고서 를 ...
#
#      article_score
# 1         0.985727
# 2         1.096174
# 3         1.074087
# 4         1.221940
# 5         0.953171
# ..             ...
# 605       1.111492
# 606       0.982914
# 607       1.084820
# 608       1.206937
# 609       0.963855
#
# [606 rows x 3 columns]

# %%
analysis_df = pd.merge(analysis_df, price, how='left', on='created_date')
analysis_df
# Out:
#     created_date                                            article  \
# 0     2018-03-16   라인의 금융 자회사 라인 파이낸셜 통해 일본 금융청에 가상화폐 거래 사업자 신청 ...
# 1     2018-03-19   콘텐츠 생산자와 추천인에게  상 는 이용자 정 로 부 독점 페이스북 등에 반기 작...
# 2     2018-03-29       도자료는 당신이 풀 노드로 돌리고 있는 블록체인에 아동 포르노가 연결되어 ...
# 3     2018-04-03                                      도자료는 으로
# 4     2018-04-04           도자료는 으로           도자료는 으로           도자료는
# ..           ...                                                ...
# 601   2021-10-21    신고점 경신한 비트코인  말엔 리스크 관리 우선해야 비트코인은 지난 일 밤 시경...
# 602   2021-10-22   일 금융위원회 위원장 고승범 는 지난 월 일 가상자산 사업자 신고 마감 이후 먹튀...
# 603   2021-10-25   조정의 끝을 알고 싶다면 만 달러 지지해야 비트코인은 일 오후 시경 만 달러 선까...
# 604   2021-10-26   미국 증권 금융의 최고 규  기구인 증권거래위원회 가 억 달러 규모의 스테이블 코...
# 605   2021-10-27    가상자산 데이터 분석 업체 글래스노드가 일 스위스 시간  간 온체인  고서 를 ...
#
#      article_score           price    before_price    label
# 0         0.985727  9024833.954689  9010234.208908 1.000000
# 1         1.096174  8970286.258314  8470860.294118 1.000000
# 2         1.074087  8437138.682345  8755687.282230 0.000000
# 3         1.221940  7904068.976898  7562219.606524 1.000000
# 4         0.953171  7943745.498499  7904068.976898 1.000000
# ..             ...             ...             ...      ...
# 601       1.111492 78874213.677081 78423109.619687 1.000000
# 602       0.982914 76632600.673195 78874213.677081 0.000000
# 603       1.084820 75178560.007318 74478050.595238 1.000000
# 604       1.206937 75581706.190764 75178560.007318 1.000000
# 605       0.963855 72994468.793601 75581706.190764 0.000000
#
# [606 rows x 6 columns]

# %%
analysis_df = analysis_df.dropna()
analysis_df['article_score'] = [str(_).replace('inf','-0.1') for _ in analysis_df['article_score']]
analysis_df['article_score'].astype(float)
analysis_df
# Out:
#     created_date                                            article  \
# 0     2018-03-16   라인의 금융 자회사 라인 파이낸셜 통해 일본 금융청에 가상화폐 거래 사업자 신청 ...
# 1     2018-03-19   콘텐츠 생산자와 추천인에게  상 는 이용자 정 로 부 독점 페이스북 등에 반기 작...
# 2     2018-03-29       도자료는 당신이 풀 노드로 돌리고 있는 블록체인에 아동 포르노가 연결되어 ...
# 3     2018-04-03                                      도자료는 으로
# 4     2018-04-04           도자료는 으로           도자료는 으로           도자료는
# ..           ...                                                ...
# 601   2021-10-21    신고점 경신한 비트코인  말엔 리스크 관리 우선해야 비트코인은 지난 일 밤 시경...
# 602   2021-10-22   일 금융위원회 위원장 고승범 는 지난 월 일 가상자산 사업자 신고 마감 이후 먹튀...
# 603   2021-10-25   조정의 끝을 알고 싶다면 만 달러 지지해야 비트코인은 일 오후 시경 만 달러 선까...
# 604   2021-10-26   미국 증권 금융의 최고 규  기구인 증권거래위원회 가 억 달러 규모의 스테이블 코...
# 605   2021-10-27    가상자산 데이터 분석 업체 글래스노드가 일 스위스 시간  간 온체인  고서 를 ...
#
#           article_score           price    before_price    label
# 0    0.9857266579564152  9024833.954689  9010234.208908 1.000000
# 1     1.096173842874322  8970286.258314  8470860.294118 1.000000
# 2    1.0740868278365687  8437138.682345  8755687.282230 0.000000
# 3    1.2219398887019521  7904068.976898  7562219.606524 1.000000
# 4    0.9531706002387889  7943745.498499  7904068.976898 1.000000
# ..                  ...             ...             ...      ...
# 601  1.1114919621256192 78874213.677081 78423109.619687 1.000000
# 602  0.9829141909273531 76632600.673195 78874213.677081 0.000000
# 603  1.0848201521959995 75178560.007318 74478050.595238 1.000000
# 604  1.2069366507603076 75581706.190764 75178560.007318 1.000000
# 605  0.9638547284415419 72994468.793601 75581706.190764 0.000000
#
# [606 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

article_scaled = pd.DataFrame(scaler.fit_transform(analysis_df[['article_score']].rolling(window=5).mean()))
price_scaled = pd.DataFrame(scaler.fit_transform(analysis_df[['price']].rolling(window=5).mean()))

s = pd.concat([article_scaled, price_scaled],axis=1)
s.columns = ['tone','price']
s
# Out:
#         tone     price
# 0        nan       nan
# 1        nan       nan
# 2        nan       nan
# 3        nan       nan
# 4   0.678774 -0.653090
# ..       ...       ...
# 601 0.807639  2.446978
# 602 0.760900  2.507616
# 603 0.784541  2.539926
# 604 0.850568  2.538290
# 605 0.694334  2.487693
#
# [606 rows x 2 columns]

# %%
plt.figure(figsize=(7,4))
plt.plot(s)
plt.title("Moving average 5 days: {}".format(article_scaled[0].corr(price_scaled[0])), fontsize=15)
plt.xlabel("Timestamp", fontsize=15)
plt.ylabel("Trend", fontsize=15)
plt.legend(s.columns,fontsize=15)
print("* corr score: ",article_scaled[0].corr(price_scaled[0]))
# Out:
# * corr score:  -0.3547286001227615
